# %%
import json
import requests
from pprint import pprint

# %%
context = requests.get(
    "https://localhost:8082/restconf/data/tapi-common:context",
    headers={
        "Authorization": "Basic YWRtaW46bm9tb3Jlc2VjcmV0"
    },
    verify=False
)
pprint(context.json())
# Out:
# /Users/carda/projects/DefragDashboard/venv/lib/python3.10/site-packages/urllib3/connectionpool.py:1095: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# {'tapi-common:context': {'name': [{'value': 'ENC/14.2.1/ROOT',
#                                    'value-name': 'SYSTEM'}],
#                          'service-interface-point': [{'administrative-state': 'UNLOCKED',
#                                                       'layer-protocol-name': 'DSR',
#                                                       'lifecycle-state': 'INSTALLED',
#                                                       'name': [{'value': '/ne=172.20.143.62/sh=3/sl=3/pt=C',
#                                                                 'value-name': 'INVENTORY_ID'},
#                                                                {'value': 'NODE62.1/3-3-C',
#                                                                 'value-name': 'USER'},
#                                                                {'value': '172.20.143.62/CH-3-3-C',
#                                                                 'value-name': 'SYSTEM'}],
#                                                       'operational-state': 'ENABLED',
#                                                       'supported-layer-protocol-qualifier': ['tapi-dsr:DIGITAL_SIGNAL_TYPE_100_GigE',
#                                                                                              'tapi-dsr:DIGITAL_SIGNAL_TYPE_OTU_4',
#                                                                                              'tapi-odu:ODU_TYPE_ODU4'],
#                                                       'uuid': '00000010-0000-0000-0000-000000046364'},
#                                                      {'administrative-state': 'LOCKED',
#                                                       'layer-protocol-name': 'DSR',
#                                                       'lifecycle-state': 'PLANNED',
#                                                       'name': [{'value': '/ne=172.20.143.64/sh=3/sl=1/pt=C',
#                                                                 'value-name': 'INVENTORY_ID'},
#                                                                {'value': 'NODE66/3-1-C',
#                                                                 'value-name': 'USER'},
#                                                                {'value': '172.20.143.64/PTP-3-1-C',
#                                                                 'value-name': 'SYSTEM'}],
#                                                       'operational-state': 'DISABLED',
#                                                       'supported-layer-protocol-qualifier': ['tapi-dsr:DIGITAL_SIGNAL_TYPE_100_GigE',
#                                                                                              'tapi-dsr:DIGITAL_SIGNAL_TYPE_OTU_4',
#                                                                                              'tapi-odu:ODU_TYPE_ODU4'],
#                                                       'uuid': '00000010-0000-0000-0000-000000047591'},
#                                                      {'administrative-state': 'UNLOCKED',
#                                                       'layer-protocol-name': 'DSR',
#                                                       'lifecycle-state': 'INSTALLED',
#                                                       'name': [{'value': '/ne=172.20.143.62/sh=3/sl=5/pt=C',
#                                                                 'value-name': 'INVENTORY_ID'},
#                                                                {'value': 'NODE62.1/3-5-C',
#                                                                 'value-name': 'USER'},
#                                                                {'value': '172.20.143.62/CH-3-5-C',
#                                                                 'value-name': 'SYSTEM'}],
#                                                       'operational-state': 'ENABLED',
#                                                       'supported-layer-protocol-qualifier': ['tapi-dsr:DIGITAL_SIGNAL_TYPE_100_GigE',
#                                                                                              'tapi-dsr:DIGITAL_SIGNAL_TYPE_OTU_4',
#                                                                                              'tapi-odu:ODU_TYPE_ODU4'],
#                                                       'uuid': '00000010-0000-0000-0000-000000046382'},
#                                                      {'administrative-state': 'LOCKED',
#                                                       'layer-protocol-name': 'ODU',
#                                                       'lifecycle-state': 'PLANNED',
#                                                       'name': [{'value': '/ne=172.20.143.64/sh=3/sl=3/pt=N',
#                                                                 'value-name': 'INVENTORY_ID'},
#                                                                {'value': 'NODE66/3-3-N',
#                                                                 'value-name': 'USER'},
#                                                                {'value': '172.20.143.64/PTP-3-3-N',
#                                                                 'value-name': 'SYSTEM'}],
#                                                       'operational-state': 'DISABLED',
#                                                       'supported-layer-protocol-qualifier': ['tapi-odu:ODU_TYPE_ODU4'],
#                                                       'uuid': '00000010-0000-0000-0000-000000047603'},
#                                                      {'administrative-state': 'UNLOCKED',
#                                                       'layer-protocol-name': 'DSR',
#                                                       'lifecycle-state': 'INSTALLED',
#                                                       'name': [{'value': '/ne=172.20.143.66/sh=3/sl=5/pt=C',
#                                                                 'value-name': 'INVENTORY_ID'},
#                                                                {'value': 'NODE70.1/3-5-C',
#                                                                 'value-name': 'USER'},
#                                                                {'value': '172.20.143.66/CH-3-5-C',
#                                                                 'value-name': 'SYSTEM'}],
#                                                       'operational-state': 'ENABLED',
#                                                       'supported-layer-protocol-qualifier': ['tapi-dsr:DIGITAL_SIGNAL_TYPE_100_GigE',
#                                                                                              'tapi-dsr:DIGITAL_SIGNAL_TYPE_OTU_4',
#                                                                                              'tapi-odu:ODU_TYPE_ODU4'],
#                                                       'uuid': '00000010-0000-0000-0000-000000048713'},
#                                                      {'administrative-state': 'LOCKED',
#                                                       'layer-protocol-name': 'ODU',
#                                                       'lifecycle-state': 'PLANNED',
#                                                       'name': [{'value': '/ne=172.20.143.64/sh=3/sl=1/pt=N',
#                                                                 'value-name': 'INVENTORY_ID'},
#                                                                {'value': 'NODE66/3-1-N',
#                                                                 'value-name': 'USER'},
#                                                                {'value': '172.20.143.64/PTP-3-1-N',
#                                                                 'value-name': 'SYSTEM'}],
#                                                       'operational-state': 'DISABLED',
#                                                       'supported-layer-protocol-qualifier': ['tapi-odu:ODU_TYPE_ODU4'],
#                                                       'uuid': '00000010-0000-0000-0000-000000047587'},
#                                                      {'administrative-state': 'LOCKED',
#                                                       'layer-protocol-name': 'ODU',
#                                                       'lifecycle-state': 'PLANNED',
#                                                       'name': [{'value': '/ne=172.20.143.62/sh=3/sl=5/pt=N',
#                                                                 'value-name': 'INVENTORY_ID'},
#                                                                {'value': 'NODE62.1/3-5-N',
#                                                                 'value-name': 'USER'},
#                                                                {'value': '172.20.143.62/PTP-3-5-N',
#                                                                 'value-name': 'SYSTEM'}],
#                                                       'operational-state': 'DISABLED',
#                                                       'supported-layer-protocol-qualifier': ['tapi-odu:ODU_TYPE_ODU4'],
#                                                       'uuid': '00000010-0000-0000-0000-000000046378'},
#                                                      {'administrative-state': 'UNLOCKED',
#                                                       'layer-protocol-name': 'DSR',
#                                                       'lifecycle-state': 'INSTALLED',
#                                                       'name': [{'value': '/ne=172.20.143.66/sh=3/sl=3/pt=C',
#                                                                 'value-name': 'INVENTORY_ID'},
#                                                                {'value': 'NODE70.1/3-3-C',
#                                                                 'value-name': 'USER'},
#                                                                {'value': '172.20.143.66/CH-3-3-C',
#                                                                 'value-name': 'SYSTEM'}],
#                                                       'operational-state': 'ENABLED',
#                                                       'supported-layer-protocol-qualifier': ['tapi-dsr:DIGITAL_SIGNAL_TYPE_100_GigE',
#                                                                                              'tapi-dsr:DIGITAL_SIGNAL_TYPE_OTU_4',
#                                                                                              'tapi-odu:ODU_TYPE_ODU4'],
#                                                       'uuid': '00000010-0000-0000-0000-000000048698'},
#                                                      {'administrative-state': 'LOCKED',
#                                                       'layer-protocol-name': 'ODU',
#                                                       'lifecycle-state': 'PLANNED',
#                                                       'name': [{'value': '/ne=172.20.143.63/sh=3/sl=3/pt=N',
#                                                                 'value-name': 'INVENTORY_ID'},
#                                                                {'value': 'NODE64/3-3-N',
#                                                                 'value-name': 'USER'},
#                                                                {'value': '172.20.143.63/PTP-3-3-N',
#                                                                 'value-name': 'SYSTEM'}],
#                                                       'operational-state': 'DISABLED',
#                                                       'supported-layer-protocol-qualifier': ['tapi-odu:ODU_TYPE_ODU4'],
#                                                       'uuid': '00000010-0000-0000-0000-000000046138'},
#                                                      {'administrative-state': 'LOCKED',
#                                                       'layer-protocol-name': 'ODU',
#                                                       'lifecycle-state': 'PLANNED',
#                                                       'name': [{'value': '/ne=172.20.143.64/sh=3/sl=5/pt=N',
#                                                                 'value-name': 'INVENTORY_ID'},
#                                                                {'value': 'NODE66/3-5-N',
#                                                                 'value-name': 'USER'},
#                                                                {'value': '172.20.143.64/PTP-3-5-N',
#                                                                 'value-name': 'SYSTEM'}],
#                                                       'operational-state': 'DISABLED',
#                                                       'supported-layer-protocol-qualifier': ['tapi-odu:ODU_TYPE_ODU4'],
#                                                       'uuid': '00000010-0000-0000-0000-000000047609'},
#                                                      {'administrative-state': 'UNLOCKED',
#                                                       'layer-protocol-name': 'DSR',
#                                                       'lifecycle-state': 'INSTALLED',
#                                                       'name': [{'value': '/ne=172.20.143.62/sh=3/sl=1/pt=C',
#                                                                 'value-name': 'INVENTORY_ID'},
#                                                                {'value': 'NODE62.1/3-1-C',
#                                                                 'value-name': 'USER'},
#                                                                {'value': '172.20.143.62/CH-3-1-C',
#                                                                 'value-name': 'SYSTEM'}],
#                                                       'operational-state': 'ENABLED',
#                                                       'supported-layer-protocol-qualifier': ['tapi-dsr:DIGITAL_SIGNAL_TYPE_100_GigE',
#                                                                                              'tapi-dsr:DIGITAL_SIGNAL_TYPE_OTU_4',
#                                                                                              'tapi-odu:ODU_TYPE_ODU4'],
#                                                       'uuid': '00000010-0000-0000-0000-000000046351'},
#                                                      {'administrative-state': 'UNLOCKED',
#                                                       'layer-protocol-name': 'DSR',
#                                                       'lifecycle-state': 'INSTALLED',
#                                                       'name': [{'value': '/ne=172.20.143.63/sh=3/sl=5/pt=C',
#                                                                 'value-name': 'INVENTORY_ID'},
#                                                                {'value': 'NODE64/3-5-C',
#                                                                 'value-name': 'USER'},
#                                                                {'value': '172.20.143.63/CH-3-5-C',
#                                                                 'value-name': 'SYSTEM'}],
#                                                       'operational-state': 'ENABLED',
#                                                       'supported-layer-protocol-qualifier': ['tapi-dsr:DIGITAL_SIGNAL_TYPE_100_GigE',
#                                                                                              'tapi-dsr:DIGITAL_SIGNAL_TYPE_OTU_4',
#                                                                                              'tapi-odu:ODU_TYPE_ODU4'],
#                                                       'uuid': '00000010-0000-0000-0000-000000046155'},
#                                                      {'administrative-state': 'UNLOCKED',
#                                                       'layer-protocol-name': 'DSR',
#                                                       'lifecycle-state': 'INSTALLED',
#                                                       'name': [{'value': '/ne=172.20.143.66/sh=3/sl=1/pt=C',
#                                                                 'value-name': 'INVENTORY_ID'},
#                                                                {'value': 'NODE70.1/3-1-C',
#                                                                 'value-name': 'USER'},
#                                                                {'value': '172.20.143.66/CH-3-1-C',
#                                                                 'value-name': 'SYSTEM'}],
#                                                       'operational-state': 'ENABLED',
#                                                       'supported-layer-protocol-qualifier': ['tapi-dsr:DIGITAL_SIGNAL_TYPE_100_GigE',
#                                                                                              'tapi-dsr:DIGITAL_SIGNAL_TYPE_OTU_4',
#                                                                                              'tapi-odu:ODU_TYPE_ODU4'],
#                                                       'uuid': '00000010-0000-0000-0000-000000048691'},
#                                                      {'administrative-state': 'LOCKED',
#                                                       'layer-protocol-name': 'ODU',
#                                                       'lifecycle-state': 'PLANNED',
#                                                       'name': [{'value': '/ne=172.20.143.63/sh=3/sl=1/pt=N',
#                                                                 'value-name': 'INVENTORY_ID'},
#                                                                {'value': 'NODE64/3-1-N',
#                                                                 'value-name': 'USER'},
#                                                                {'value': '172.20.143.63/PTP-3-1-N',
#                                                                 'value-name': 'SYSTEM'}],
#                                                       'operational-state': 'DISABLED',
#                                                       'supported-layer-protocol-qualifier': ['tapi-odu:ODU_TYPE_ODU4'],
#                                                       'uuid': '00000010-0000-0000-0000-000000046095'},
#                                                      {'administrative-state': 'LOCKED',
#                                                       'layer-protocol-name': 'ODU',
#                                                       'lifecycle-state': 'PLANNED',
#                                                       'name': [{'value': '/ne=172.20.143.63/sh=3/sl=5/pt=N',
#                                                                 'value-name': 'INVENTORY_ID'},
#                                                                {'value': 'NODE64/3-5-N',
#                                                                 'value-name': 'USER'},
#                                                                {'value': '172.20.143.63/PTP-3-5-N',
#                                                                 'value-name': 'SYSTEM'}],
#                                                       'operational-state': 'DISABLED',
#                                                       'supported-layer-protocol-qualifier': ['tapi-odu:ODU_TYPE_ODU4'],
#                                                       'uuid': '00000010-0000-0000-0000-000000046150'},
#                                                      {'administrative-state': 'LOCKED',
#                                                       'layer-protocol-name': 'ODU',
#                                                       'lifecycle-state': 'PLANNED',
#                                                       'name': [{'value': '/ne=172.20.143.66/sh=3/sl=3/pt=N',
#                                                                 'value-name': 'INVENTORY_ID'},
#                                                                {'value': 'NODE70.1/3-3-N',
#                                                                 'value-name': 'USER'},
#                                                                {'value': '172.20.143.66/PTP-3-3-N',
#                                                                 'value-name': 'SYSTEM'}],
#                                                       'operational-state': 'DISABLED',
#                                                       'supported-layer-protocol-qualifier': ['tapi-odu:ODU_TYPE_ODU4'],
#                                                       'uuid': '00000010-0000-0000-0000-000000048703'},
#                                                      {'administrative-state': 'UNLOCKED',
#                                                       'layer-protocol-name': 'DSR',
#                                                       'lifecycle-state': 'INSTALLED',
#                                                       'name': [{'value': '/ne=172.20.143.64/sh=3/sl=5/pt=C',
#                                                                 'value-name': 'INVENTORY_ID'},
#                                                                {'value': 'NODE66/3-5-C',
#                                                                 'value-name': 'USER'},
#                                                                {'value': '172.20.143.64/CH-3-5-C',
#                                                                 'value-name': 'SYSTEM'}],
#                                                       'operational-state': 'ENABLED',
#                                                       'supported-layer-protocol-qualifier': ['tapi-dsr:DIGITAL_SIGNAL_TYPE_100_GigE',
#                                                                                              'tapi-dsr:DIGITAL_SIGNAL_TYPE_OTU_4',
#                                                                                              'tapi-odu:ODU_TYPE_ODU4'],
#                                                       'uuid': '00000010-0000-0000-0000-000000047613'},
#                                                      {'administrative-state': 'UNLOCKED',
#                                                       'layer-protocol-name': 'DSR',
#                                                       'lifecycle-state': 'INSTALLED',
#                                                       'name': [{'value': '/ne=172.20.143.63/sh=3/sl=3/pt=C',
#                                                                 'value-name': 'INVENTORY_ID'},
#                                                                {'value': 'NODE64/3-3-C',
#                                                                 'value-name': 'USER'},
#                                                                {'value': '172.20.143.63/CH-3-3-C',
#                                                                 'value-name': 'SYSTEM'}],
#                                                       'operational-state': 'ENABLED',
#                                                       'supported-layer-protocol-qualifier': ['tapi-dsr:DIGITAL_SIGNAL_TYPE_100_GigE',
#                                                                                              'tapi-dsr:DIGITAL_SIGNAL_TYPE_OTU_4',
#                                                                                              'tapi-odu:ODU_TYPE_ODU4'],
#                                                       'uuid': '00000010-0000-0000-0000-000000046129'},
#                                                      {'administrative-state': 'LOCKED',
#                                                       'layer-protocol-name': 'ODU',
#                                                       'lifecycle-state': 'PLANNED',
#                                                       'name': [{'value': '/ne=172.20.143.62/sh=3/sl=1/pt=N',
#                                                                 'value-name': 'INVENTORY_ID'},
#                                                                {'value': 'NODE62.1/3-1-N',
#                                                                 'value-name': 'USER'},
#                                                                {'value': '172.20.143.62/PTP-3-1-N',
#                                                                 'value-name': 'SYSTEM'}],
#                                                       'operational-state': 'DISABLED',
#                                                       'supported-layer-protocol-qualifier': ['tapi-odu:ODU_TYPE_ODU4'],
#                                                       'uuid': '00000010-0000-0000-0000-000000046344'},
#                                                      {'administrative-state': 'UNLOCKED',
#                                                       'layer-protocol-name': 'DSR',
#                                                       'lifecycle-state': 'INSTALLED',
#                                                       'name': [{'value': '/ne=172.20.143.64/sh=3/sl=3/pt=C',
#                                                                 'value-name': 'INVENTORY_ID'},
#                                                                {'value': 'NODE66/3-3-C',
#                                                                 'value-name': 'USER'},
#                                                                {'value': '172.20.143.64/CH-3-3-C',
#                                                                 'value-name': 'SYSTEM'}],
#                                                       'operational-state': 'ENABLED',
#                                                       'supported-layer-protocol-qualifier': ['tapi-dsr:DIGITAL_SIGNAL_TYPE_100_GigE',
#                                                                                              'tapi-dsr:DIGITAL_SIGNAL_TYPE_OTU_4',
#                                                                                              'tapi-odu:ODU_TYPE_ODU4'],
#                                                       'uuid': '00000010-0000-0000-0000-000000047598'},
#                                                      {'administrative-state': 'UNLOCKED',
#                                                       'layer-protocol-name': 'DSR',
#                                                       'lifecycle-state': 'INSTALLED',
#                                                       'name': [{'value': '/ne=172.20.143.63/sh=3/sl=1/pt=C',
#                                                                 'value-name': 'INVENTORY_ID'},
#                                                                {'value': 'NODE64/3-1-C',
#                                                                 'value-name': 'USER'},
#                                                                {'value': '172.20.143.63/CH-3-1-C',
#                                                                 'value-name': 'SYSTEM'}],
#                                                       'operational-state': 'ENABLED',
#                                                       'supported-layer-protocol-qualifier': ['tapi-dsr:DIGITAL_SIGNAL_TYPE_100_GigE',
#                                                                                              'tapi-dsr:DIGITAL_SIGNAL_TYPE_OTU_4',
#                                                                                              'tapi-odu:ODU_TYPE_ODU4'],
#                                                       'uuid': '00000010-0000-0000-0000-000000046102'},
#                                                      {'administrative-state': 'LOCKED',
#                                                       'layer-protocol-name': 'ODU',
#                                                       'lifecycle-state': 'PLANNED',
#                                                       'name': [{'value': '/ne=172.20.143.66/sh=3/sl=1/pt=N',
#                                                                 'value-name': 'INVENTORY_ID'},
#                                                                {'value': 'NODE70.1/3-1-N',
#                                                                 'value-name': 'USER'},
#                                                                {'value': '172.20.143.66/PTP-3-1-N',
#                                                                 'value-name': 'SYSTEM'}],
#                                                       'operational-state': 'DISABLED',
#                                                       'supported-layer-protocol-qualifier': ['tapi-odu:ODU_TYPE_ODU4'],
#                                                       'uuid': '00000010-0000-0000-0000-000000048687'},
#                                                      {'administrative-state': 'LOCKED',
#                                                       'layer-protocol-name': 'ODU',
#                                                       'lifecycle-state': 'PLANNED',
#                                                       'name': [{'value': '/ne=172.20.143.62/sh=3/sl=3/pt=N',
#                                                                 'value-name': 'INVENTORY_ID'},
#                                                                {'value': 'NODE62.1/3-3-N',
#                                                                 'value-name': 'USER'},
#                                                                {'value': '172.20.143.62/PTP-3-3-N',
#                                                                 'value-name': 'SYSTEM'}],
#                                                       'operational-state': 'DISABLED',
#                                                       'supported-layer-protocol-qualifier': ['tapi-odu:ODU_TYPE_ODU4'],
#                                                       'uuid': '00000010-0000-0000-0000-000000046369'},
#                                                      {'administrative-state': 'LOCKED',
#                                                       'layer-protocol-name': 'ODU',
#                                                       'lifecycle-state': 'PLANNED',
#                                                       'name': [{'value': '/ne=172.20.143.66/sh=3/sl=5/pt=N',
#                                                                 'value-name': 'INVENTORY_ID'},
#                                                                {'value': 'NODE70.1/3-5-N',
#                                                                 'value-name': 'USER'},
#                                                                {'value': '172.20.143.66/PTP-3-5-N',
#                                                                 'value-name': 'SYSTEM'}],
#                                                       'operational-state': 'DISABLED',
#                                                       'supported-layer-protocol-qualifier': ['tapi-odu:ODU_TYPE_ODU4'],
#                                                       'uuid': '00000010-0000-0000-0000-000000048709'}],
#                          'tapi-connectivity:connectivity-context': {'connection': [{'connection-end-point': [{'connection-end-point-uuid': '30000050-0000-0000-0000-000000048552',
#                                                                                                               'node-edge-point-uuid': '30000040-0000-0000-0000-000000048552',
#                                                                                                               'node-uuid': '00000030-0000-0000-0000-000000048451',
#                                                                                                               'topology-uuid': '00000020-0000-0000-0000-000000000003'},
#                                                                                                              {'connection-end-point-uuid': '30000050-0000-0000-0000-000000048721',
#                                                                                                               'node-edge-point-uuid': '30000040-0000-0000-0000-000000048721',
#                                                                                                               'node-uuid': '00000030-0000-0000-0000-000000048451',
#                                                                                                               'topology-uuid': '00000020-0000-0000-0000-000000000003'}],
#                                                                                     'direction': 'BIDIRECTIONAL',
#                                                                                     'layer-protocol-name': 'PHOTONIC_MEDIA',
#                                                                                     'lifecycle-state': 'INSTALLED',
#                                                                                     'name': [{'value': 'OTS '
#                                                                                                        '- '
#                                                                                                        '172.20.143.66/PTP-2-12-N '
#                                                                                                        '- '
#                                                                                                        '172.20.143.66/PTP-2',
#                                                                                               'value-name': 'SYSTEM'},
#                                                                                              {'value': 'OTS '
#                                                                                                        '- '
#                                                                                                        '/ne=172.20.143.66/sh=2/sl=12/pt=N '
#                                                                                                        '- '
#                                                                                                        '/ne=172.20.143.66/pt=OL-2',
#                                                                                               'value-name': 'INVENTORY_ID'}],
#                                                                                     'operational-state': 'ENABLED',
#                                                                                     'uuid': '00000080-0000-0004-8552-000000048721'},
#                                                                                    {'connection-end-point': [{'connection-end-point-uuid': '30010050-0000-0000-0000-000000046315',
#                                                                                                               'node-edge-point-uuid': '30010040-0000-0000-0000-000000046315',
#                                                                                                               'node-uuid': '00000030-0000-0000-0000-000000045888',
#                                                                                                               'topology-uuid': '00000020-0000-0000-0000-000000000003'},
#                                                                                                              {'connection-end-point-uuid': '30010050-0000-0000-0000-000000046171',
#                                                                                                               'node-edge-point-uuid': '30010040-0000-0000-0000-000000046171',
#                                                                                                               'node-uuid': '00000030-0000-0000-0000-000000045888',
#                                                                                                               'topology-uuid': '00000020-0000-0000-0000-000000000003'}],
#                                                                                     'direction': 'BIDIRECTIONAL',
#                                                                                     'layer-protocol-name': 'PHOTONIC_MEDIA',
#                                                                                     'lifecycle-state': 'INSTALLED',
#                                                                                     'name': [{'value': 'OMS '
#                                                                                                        '- '
#                                                                                                        '172.20.143.62/PTP-2-7-N '
#                                                                                                        '- '
#                                                                                                        '172.20.143.62/PTP-2-14-N',
#                                                                                               'value-name': 'SYSTEM'},
#                                                                                              {'value': 'OMS '
#                                                                                                        '- '
#                                                                                                        '/ne=172.20.143.62/sh=2/sl=7/pt=N '
#                                                                                                        '- '
#                                                                                                        '/ne=172.20.143.62/sh=2/sl=14/pt=N',
#                                                                                               'value-name': 'INVENTORY_ID'}],
#                                                                                     'operational-state': 'ENABLED',
#                                                                                     'uuid': '00000080-0000-0004-6315-000000046171'},
#                                                                                    {'connection-end-point': [{'connection-end-point-uuid': '30000050-0000-0000-0000-000000047378',
#                                                                                                               'node-edge-point-uuid': '30000040-0000-0000-0000-000000047378',
#                                                                                                               'node-uuid': '00000030-0000-0000-0000-000000047277',
#                                                                                                               'topology-uuid': '00000020-0000-0000-0000-000000000003'},
#                                                                                                              {'connection-end-point-uuid': '30000050-0000-0000-0000-000000046099',
#                                                                                                               'node-edge-point-uuid': '30000040-0000-0000-0000-000000046099',
#                                                                                                               'node-uuid': '00000030-0000-0000-0000-000000045888',
#                                                                                                               'topology-uuid': '00000020-0000-0000-0000-000000000003'}],
#                                                                                     'direction': 'BIDIRECTIONAL',
#                                                                                     'layer-protocol-name': 'PHOTONIC_MEDIA',
#                                                                                     'lifecycle-state': 'INSTALLED',
#                                                                                     'lower-connection': [{'connection-uuid': '00000080-0000-0004-7378-000000047618'},
#                                                                                                          {'connection-uuid': '00000080-0000-0004-6454-000000046099'}],
#                                                                                     'name': [{'value': 'OTS '
#                                                                                                        '- '
#                                                                                                        '172.20.143.64/PTP-2-12-N '
#                                                                                                        '- '
#                                                                                                        '172.20.143.62/PTP-2-12-N',
#                                                                                               'value-name': 'SYSTEM'},
#                                                                                              {'value': 'OTS '
#                                                                                                        '- '
#                                                                                                        '/ne=172.20.143.64/sh=2/sl=12/pt=N '
#                                                                                                        '- '
#                                                                                                        '/ne=172.20.143.62/sh=2/sl=12/pt=N',
#                                                                                               'value-name': 'INVENTORY_ID'},
#                                                                                              {'value': 'OPTICAL(OTS): '
#                                                                                                        'NODE66/OM-2-12-N '
#                                                                                                        '--- '
#                                                                                                        'NODE62.1/OM-2-12-N',
#                                                                                               'value-name': 'USER'}],
#                                                                                     'operational-state': 'ENABLED',
#                                                                                     'route': [{'connection-end-point': [{'connection-end-point-uuid': '30000050-0000-0000-0000-000000047378',
#                                                                                                                          'node-edge-point-uuid': '30000040-0000-0000-0000-000000047378',
#                                                                                                                          'node-uuid': '00000030-0000-0000-0000-000000047277',
#                                                                                                                          'topology-uuid': '00000020-0000-0000-0000-000000000003'},
#                                                                                                                         {'connection-end-point-uuid': '30000050-0000-0000-0000-000000047618',
#                                                                                                                          'node-edge-point-uuid': '30000040-0000-0000-0000-000000047618',
#                                                                                                                          'node-uuid': '00000030-0000-0000-0000-000000047277',
#                                                                                                                          'topology-uuid': '00000020-0000-0000-0000-000000000003'},
#                                                                                                                         {'connection-end-point-uuid': '30000050-0000-0000-0000-000000046454',
#                                                                                                                          'node-edge-point-uuid': '30000040-0000-0000-0000-000000046454',
#                                                                                                                          'node-uuid': '00000030-0000-0000-0000-000000045888',
#                                                                                                                          'topology-uuid': '00000020-0000-0000-0000-000000000003'},
#                                                                                                                         {'connection-end-point-uuid': '30000050-0000-0000-0000-000000046099',
#                                                                                                                          'node-edge-point-uuid': '30000040-0000-0000-0000-000000046099',
#                                                                                                                          'node-uuid': '00000030-0000-0000-0000-000000045888',
#                                                                                                                          'topology-uuid': '00000020-0000-0000-0000-000000000003'}],
#                                                                                                'local-id': '47724',
#                                                                                                'name': [{'value': 'OTS '
#                                                                                                                   '- '
#                                                                                                                   '172.20.143.64/PTP-2-12-N '
#                                                                                                                   '- '
#                                                                                                                   '172.20.143.62/PTP-2-12-N/47724',
#                                                                                                          'value-name': 'SYSTEM'},
#                                                                                                         {'value': 'OTS '
#                                                                                                                   '- '
#                                                                                                                   '/ne=172.20.143.64/sh=2/sl=12/pt=N '
#                                                                                                                   '- '
#                                                                                                                   '/ne=172.20.143.62/sh=2/sl=12/pt=N/47724',
#                                                                                                          'value-name': 'INVENTORY_ID'},
#                                                                                                         {'value': 'OPTICAL(OTS): '
#                                                                                                                   'NODE66/OM-2-12-N '
#                                                                                                                   '--- '
#                                                                                                                   'NODE62.1/OM-2-12-N/47724',
#                                                                                                          'value-name': 'USER'}]}],
#                                                                                     'supported-client-link': [{'link-uuid': '30010060-0000-0000-0000-000000047731',
#                                                                                                                'topology-uuid': '00000020-0000-0000-0000-000000000003'}],
#                                                                                     'tapi-adva:adva-connection-spec': {'physical-route': [{'directionality': 'bidirectional',
#                                                                                                                                            'route-object': [{'device-name': 'NODE66',
# ...
#                                                                                                                         {'value': '172.20.143.63/OM-2-1-N',
#                                                                                                                          'value-name': 'SYSTEM'}],
#                                                                                                                'operational-state': 'DISABLED',
#                                                                                                                'supported-cep-layer-protocol-qualifier': ['tapi-photonic-media:PHOTONIC_LAYER_QUALIFIER_OCH'],
#                                                                                                                'tapi-connectivity:cep-list': {'connection-end-point': []},
#                                                                                                                'tapi-photonic-media:media-channel-node-edge-point-spec': {'mc-pool': {'available-spectrum': [{'frequency-constraint': {'adjustment-granularity': 'G_50GHZ',
#                                                                                                                                                                                                                                        'grid-type': 'DWDM'},
#                                                                                                                                                                                                               'lower-frequency': '191212500',
#                                                                                                                                                                                                               'upper-frequency': '196125000'}],
#                                                                                                                                                                                       'occupied-spectrum': [],
#                                                                                                                                                                                       'supportable-spectrum': [{'frequency-constraint': {'adjustment-granularity': 'G_50GHZ',
#                                                                                                                                                                                                                                          'grid-type': 'DWDM'},
#                                                                                                                                                                                                                 'lower-frequency': '191212500',
#                                                                                                                                                                                                                 'upper-frequency': '196125000'}]}},
#                                                                                                                'termination-direction': 'BIDIRECTIONAL',
#                                                                                                                'termination-state': 'TERMINATED_BIDIRECTIONAL',
#                                                                                                                'uuid': '30040040-0000-0000-0000-000000045772'},
#                                                                                                               {'administrative-state': 'UNLOCKED',
#                                                                                                                'layer-protocol-name': 'PHOTONIC_MEDIA',
#                                                                                                                'lifecycle-state': 'INSTALLED',
#                                                                                                                'link-port-direction': 'BIDIRECTIONAL',
#                                                                                                                'mapped-service-interface-point': [],
#                                                                                                                'name': [{'value': '/ne=172.20.143.63/sh=2/sl=4/pt=N',
#                                                                                                                          'value-name': 'INVENTORY_ID'},
#                                                                                                                         {'value': 'NODE64/2-4-N',
#                                                                                                                          'value-name': 'USER'},
#                                                                                                                         {'value': '172.20.143.63/OM-2-4-N',
#                                                                                                                          'value-name': 'SYSTEM'}],
#                                                                                                                'operational-state': 'DISABLED',
#                                                                                                                'supported-cep-layer-protocol-qualifier': ['tapi-photonic-media:PHOTONIC_LAYER_QUALIFIER_OCH'],
#                                                                                                                'tapi-connectivity:cep-list': {'connection-end-point': []},
#                                                                                                                'tapi-photonic-media:media-channel-node-edge-point-spec': {'mc-pool': {'available-spectrum': [{'frequency-constraint': {'adjustment-granularity': 'G_50GHZ',
#                                                                                                                                                                                                                                        'grid-type': 'DWDM'},
#                                                                                                                                                                                                               'lower-frequency': '191212500',
#                                                                                                                                                                                                               'upper-frequency': '196125000'}],
#                                                                                                                                                                                       'occupied-spectrum': [],
#                                                                                                                                                                                       'supportable-spectrum': [{'frequency-constraint': {'adjustment-granularity': 'G_50GHZ',
#                                                                                                                                                                                                                                          'grid-type': 'DWDM'},
#                                                                                                                                                                                                                 'lower-frequency': '191212500',
#                                                                                                                                                                                                                 'upper-frequency': '196125000'}]}},
#                                                                                                                'termination-direction': 'BIDIRECTIONAL',
#                                                                                                                'termination-state': 'TERMINATED_BIDIRECTIONAL',
#                                                                                                                'uuid': '30040040-0000-0000-0000-000000046072'},
#                                                                                                               {'administrative-state': 'LOCKED',
#                                                                                                                'layer-protocol-name': 'PHOTONIC_MEDIA',
#                                                                                                                'lifecycle-state': 'PLANNED',
#                                                                                                                'link-port-direction': 'BIDIRECTIONAL',
#                                                                                                                'mapped-service-interface-point': [{'service-interface-point-uuid': '00000010-0000-0000-0000-000000046095'}],
#                                                                                                                'name': [{'value': '/ne=172.20.143.63/sh=3/sl=1/pt=N',
#                                                                                                                          'value-name': 'INVENTORY_ID'},
#                                                                                                                         {'value': 'NODE64/3-1-N',
#                                                                                                                          'value-name': 'USER'},
#                                                                                                                         {'value': '172.20.143.63/PTP-3-1-N',
#                                                                                                                          'value-name': 'SYSTEM'}],
#                                                                                                                'operational-state': 'DISABLED',
#                                                                                                                'supported-cep-layer-protocol-qualifier': ['tapi-photonic-media:PHOTONIC_LAYER_QUALIFIER_OCH'],
#                                                                                                                'tapi-connectivity:cep-list': {'connection-end-point': []},
#                                                                                                                'tapi-photonic-media:media-channel-node-edge-point-spec': {'mc-pool': {'available-spectrum': [],
#                                                                                                                                                                                       'occupied-spectrum': [],
#                                                                                                                                                                                       'supportable-spectrum': []}},
#                                                                                                                'termination-direction': 'BIDIRECTIONAL',
#                                                                                                                'termination-state': 'TERMINATED_BIDIRECTIONAL',
#                                                                                                                'uuid': '30040040-0000-0000-0000-000000046095'},
#                                                                                                               {'administrative-state': 'LOCKED',
#                                                                                                                'layer-protocol-name': 'DSR',
#                                                                                                                'lifecycle-state': 'PLANNED',
#                                                                                                                'link-port-direction': 'BIDIRECTIONAL',
#                                                                                                                'mapped-service-interface-point': [{'service-interface-point-uuid': '00000010-0000-0000-0000-000000046095'}],
#                                                                                                                'name': [{'value': '/ne=172.20.143.63/sh=3/sl=1/pt=N',
#                                                                                                                          'value-name': 'INVENTORY_ID'},
#                                                                                                                         {'value': 'NODE64/3-1-N',
#                                                                                                                          'value-name': 'USER'},
#                                                                                                                         {'value': '172.20.143.63/PTP-3-1-N',
#                                                                                                                          'value-name': 'SYSTEM'}],
#                                                                                                                'operational-state': 'DISABLED',
#                                                                                                                'supported-cep-layer-protocol-qualifier': ['tapi-dsr:DIGITAL_SIGNAL_TYPE_100_GigE'],
#                                                                                                                'tapi-connectivity:cep-list': {'connection-end-point': []},
#                                                                                                                'termination-direction': 'BIDIRECTIONAL',
#                                                                                                                'termination-state': 'TERMINATED_BIDIRECTIONAL',
#                                                                                                                'uuid': '20000040-0000-0000-0000-000000046095'}],
#                                                                                     'tapi-adva:adva-node-spec': {'adva-administrative-state': 'IN_SERVICE',
#                                                                                                                  'cp-mode': 'CPD',
#                                                                                                                  'ip-address': '172.20.143.63',
#                                                                                                                  'ne-type': 'FSP '
#                                                                                                                             '3000R7',
#                                                                                                                  'reachability-status': 'REACHABLE',
#                                                                                                                  'serial-number': '',
#                                                                                                                  'sw-version': '20.3.1',
#                                                                                                                  'user-label': 'NODE64'},
#                                                                                     'uuid': '00000030-0000-0000-0000-000000045758'}],
#                                                                           'uuid': '00000020-0000-0000-0000-000000000003'}]}}}

# %%
context.json()
with open("context.json", "wt", encoding="UTF-8") as file:
    json.dump(context.json(), file)

# %%
content = context.json()
print(content["tapi-common:context"].keys())
# Out:
# dict_keys(['tapi-connectivity:connectivity-context', 'name', 'service-interface-point', 'tapi-topology:topology-context'])

# %%
print("name:")
print(content["tapi-common:context"]["name"])
# Out:
# name:
# [{'value': 'ENC/14.2.1/ROOT', 'value-name': 'SYSTEM'}]

# %%
print("tapi-topology:topology-context:")
pprint(content["tapi-common:context"]["tapi-topology:topology-context"]["topology"][0]["node"][0])
# Out:
# tapi-topology:topology-context:
# {'cost-characteristic': [{'cost-name': 'NOT_SUPPORTED_MANDATORY_FIELD'}],
#  'latency-characteristic': [{'traffic-property-name': 'NOT_SUPPORTED_MANDATORY_FIELD'}],
#  'layer-protocol-name': ['PHOTONIC_MEDIA', 'DSR', 'ODU'],
#  'lifecycle-state': 'INSTALLED',
#  'name': [{'value': 'NODE66', 'value-name': 'USER'},
#           {'value': '172.20.143.64', 'value-name': 'SYSTEM'},
#           {'value': '/ne=172.20.143.64', 'value-name': 'INVENTORY_ID'}],
#  'operational-state': 'ENABLED',
#  'owned-node-edge-point': [{'administrative-state': 'LOCKED',
#                             'layer-protocol-name': 'DSR',
#                             'lifecycle-state': 'PLANNED',
#                             'link-port-direction': 'BIDIRECTIONAL',
#                             'mapped-service-interface-point': [{'service-interface-point-uuid': '00000010-0000-0000-0000-000000047591'}],
#                             'name': [{'value': '/ne=172.20.143.64/sh=3/sl=1/pt=C',
#                                       'value-name': 'INVENTORY_ID'},
#                                      {'value': 'NODE66/3-1-C',
#                                       'value-name': 'USER'},
#                                      {'value': '172.20.143.64/PTP-3-1-C',
#                                       'value-name': 'SYSTEM'}],
#                             'operational-state': 'DISABLED',
#                             'supported-cep-layer-protocol-qualifier': ['tapi-dsr:DIGITAL_SIGNAL_TYPE_100_GigE',
#                                                                        'tapi-dsr:DIGITAL_SIGNAL_TYPE_OTU_4'],
#                             'tapi-connectivity:cep-list': {'connection-end-point': [{'client-node-edge-point': [],
#                                                                                      'connection-port-direction': 'BIDIRECTIONAL',
#                                                                                      'layer-protocol-name': 'DSR',
#                                                                                      'layer-protocol-qualifier': 'tapi-dsr:DIGITAL_SIGNAL_TYPE_100_GigE',
#                                                                                      'lifecycle-state': 'PLANNED',
#                                                                                      'name': [{'value': '/ne=172.20.143.64/sh=3/sl=1/pt=C',
#                                                                                                'value-name': 'INVENTORY_ID'},
#                                                                                               {'value': 'NODE66/3-1-C',
#                                                                                                'value-name': 'USER'},
#                                                                                               {'value': '172.20.143.64/PTP-3-1-C',
#                                                                                                'value-name': 'SYSTEM'}],
#                                                                                      'operational-state': 'DISABLED',
#                                                                                      'parent-node-edge-point': {'node-edge-point-uuid': '20000040-0000-0000-0000-000000047591',
#                                                                                                                 'node-uuid': '00000030-0000-0000-0000-000000047277',
#                                                                                                                 'topology-uuid': '00000020-0000-0000-0000-000000000003'},
#                                                                                      'tapi-adva:adva-connection-end-point-spec': {},
#                                                                                      'termination-state': 'TERMINATED_BIDIRECTIONAL',
#                                                                                      'uuid': '20050050-0000-0000-0000-000000047591'}]},
#                             'termination-direction': 'BIDIRECTIONAL',
#                             'termination-state': 'TERMINATED_BIDIRECTIONAL',
#                             'uuid': '20000040-0000-0000-0000-000000047591'},
#                            {'administrative-state': 'LOCKED',
#                             'layer-protocol-name': 'ODU',
#                             'lifecycle-state': 'PLANNED',
#                             'link-port-direction': 'BIDIRECTIONAL',
#                             'mapped-service-interface-point': [{'service-interface-point-uuid': '00000010-0000-0000-0000-000000047587'}],
#                             'name': [{'value': '/ne=172.20.143.64/sh=3/sl=1/pt=N',
#                                       'value-name': 'INVENTORY_ID'},
#                                      {'value': 'NODE66/3-1-N',
#                                       'value-name': 'USER'},
#                                      {'value': '172.20.143.64/PTP-3-1-N',
#                                       'value-name': 'SYSTEM'}],
#                             'operational-state': 'DISABLED',
#                             'supported-cep-layer-protocol-qualifier': ['tapi-odu:ODU_TYPE_ODU4'],
#                             'tapi-connectivity:cep-list': {'connection-end-point': [{'client-node-edge-point': [],
#                                                                                      'connection-port-direction': 'BIDIRECTIONAL',
#                                                                                      'layer-protocol-name': 'ODU',
#                                                                                      'layer-protocol-qualifier': 'tapi-odu:ODU_TYPE_ODU4',
#                                                                                      'lifecycle-state': 'PLANNED',
#                                                                                      'name': [{'value': '/ne=172.20.143.64/sh=3/sl=1/pt=N',
#                                                                                                'value-name': 'INVENTORY_ID'},
#                                                                                               {'value': 'NODE66/3-1-N',
#                                                                                                'value-name': 'USER'},
#                                                                                               {'value': '172.20.143.64/PTP-3-1-N',
#                                                                                                'value-name': 'SYSTEM'}],
#                                                                                      'operational-state': 'DISABLED',
#                                                                                      'parent-node-edge-point': {'node-edge-point-uuid': '00060040-0000-0000-0000-000000047587',
#                                                                                                                 'node-uuid': '00000030-0000-0000-0000-000000047277',
#                                                                                                                 'topology-uuid': '00000020-0000-0000-0000-000000000003'},
#                                                                                      'tapi-adva:adva-connection-end-point-spec': {},
#                                                                                      'tapi-odu:odu-connection-end-point-spec': {'odu-common': {'odu-rate': '104794445',
#                                                                                                                                                'odu-rate-tolerance': '20',
#                                                                                                                                                'odu-type': 'tapi-odu:ODU_TYPE_ODU4'},
#                                                                                                                                 'odu-protection': {'aps-enable': False},
#                                                                                                                                 'odu-term-and-adapter': {'auto-payload-type': False,
#                                                                                                                                                          'opu-tributary-slot-size': '1G25'}},
#                                                                                      'termination-state': 'TERMINATED_BIDIRECTIONAL',
#                                                                                      'uuid': '00060050-0000-0000-0000-000000047587'}]},
#                             'tapi-odu:odu-node-edge-point-spec': {'odu-pool': {'client-capacity': '104794445'}},
#                             'termination-direction': 'BIDIRECTIONAL',
#                             'termination-state': 'TERMINATED_BIDIRECTIONAL',
#                             'uuid': '00060040-0000-0000-0000-000000047587'},
#                            {'administrative-state': 'UNLOCKED',
#                             'layer-protocol-name': 'DSR',
#                             'lifecycle-state': 'INSTALLED',
#                             'link-port-direction': 'BIDIRECTIONAL',
#                             'mapped-service-interface-point': [{'service-interface-point-uuid': '00000010-0000-0000-0000-000000047598'}],
#                             'name': [{'value': '/ne=172.20.143.64/sh=3/sl=3/pt=C',
#                                       'value-name': 'INVENTORY_ID'},
#                                      {'value': 'NODE66/3-3-C',
#                                       'value-name': 'USER'},
#                                      {'value': '172.20.143.64/CH-3-3-C',
#                                       'value-name': 'SYSTEM'}],
#                             'operational-state': 'ENABLED',
#                             'supported-cep-layer-protocol-qualifier': ['tapi-dsr:DIGITAL_SIGNAL_TYPE_100_GigE',
#                                                                        'tapi-dsr:DIGITAL_SIGNAL_TYPE_OTU_4'],
#                             'tapi-connectivity:cep-list': {'connection-end-point': []},
#                             'termination-direction': 'BIDIRECTIONAL',
#                             'termination-state': 'TERMINATED_BIDIRECTIONAL',
#                             'uuid': '20000040-0000-0000-0000-000000047598'},
#                            {'administrative-state': 'LOCKED',
#                             'layer-protocol-name': 'ODU',
#                             'lifecycle-state': 'PLANNED',
#                             'link-port-direction': 'BIDIRECTIONAL',
#                             'mapped-service-interface-point': [{'service-interface-point-uuid': '00000010-0000-0000-0000-000000047603'}],
#                             'name': [{'value': '/ne=172.20.143.64/sh=3/sl=3/pt=N',
#                                       'value-name': 'INVENTORY_ID'},
#                                      {'value': 'NODE66/3-3-N',
#                                       'value-name': 'USER'},
#                                      {'value': '172.20.143.64/PTP-3-3-N',
#                                       'value-name': 'SYSTEM'}],
#                             'operational-state': 'DISABLED',
#                             'supported-cep-layer-protocol-qualifier': ['tapi-odu:ODU_TYPE_ODU4'],
#                             'tapi-connectivity:cep-list': {'connection-end-point': []},
#                             'tapi-odu:odu-node-edge-point-spec': {'odu-pool': {'client-capacity': '104794445'}},
#                             'termination-direction': 'BIDIRECTIONAL',
#                             'termination-state': 'TERMINATED_BIDIRECTIONAL',
#                             'uuid': '00060040-0000-0000-0000-000000047603'},
#                            {'administrative-state': 'LOCKED',
#                             'layer-protocol-name': 'ODU',
#                             'lifecycle-state': 'PLANNED',
#                             'link-port-direction': 'BIDIRECTIONAL',
#                             'mapped-service-interface-point': [{'service-interface-point-uuid': '00000010-0000-0000-0000-000000047609'}],
#                             'name': [{'value': '/ne=172.20.143.64/sh=3/sl=5/pt=N',
#                                       'value-name': 'INVENTORY_ID'},
#                                      {'value': 'NODE66/3-5-N',
#                                       'value-name': 'USER'},
#                                      {'value': '172.20.143.64/PTP-3-5-N',
#                                       'value-name': 'SYSTEM'}],
#                             'operational-state': 'DISABLED',
#                             'supported-cep-layer-protocol-qualifier': ['tapi-odu:ODU_TYPE_ODU4'],
#                             'tapi-connectivity:cep-list': {'connection-end-point': []},
#                             'tapi-odu:odu-node-edge-point-spec': {'odu-pool': {'client-capacity': '104794445'}},
#                             'termination-direction': 'BIDIRECTIONAL',
#                             'termination-state': 'TERMINATED_BIDIRECTIONAL',
#                             'uuid': '00060040-0000-0000-0000-000000047609'},
#                            {'administrative-state': 'UNLOCKED',
#                             'layer-protocol-name': 'DSR',
#                             'lifecycle-state': 'INSTALLED',
#                             'link-port-direction': 'BIDIRECTIONAL',
#                             'mapped-service-interface-point': [{'service-interface-point-uuid': '00000010-0000-0000-0000-000000047613'}],
#                             'name': [{'value': '/ne=172.20.143.64/sh=3/sl=5/pt=C',
#                                       'value-name': 'INVENTORY_ID'},
#                                      {'value': 'NODE66/3-5-C',
#                                       'value-name': 'USER'},
#                                      {'value': '172.20.143.64/CH-3-5-C',
#                                       'value-name': 'SYSTEM'}],
#                             'operational-state': 'ENABLED',
#                             'supported-cep-layer-protocol-qualifier': ['tapi-dsr:DIGITAL_SIGNAL_TYPE_100_GigE',
#                                                                        'tapi-dsr:DIGITAL_SIGNAL_TYPE_OTU_4'],
#                             'tapi-connectivity:cep-list': {'connection-end-point': []},
#                             'termination-direction': 'BIDIRECTIONAL',
#                             'termination-state': 'TERMINATED_BIDIRECTIONAL',
#                             'uuid': '20000040-0000-0000-0000-000000047613'},
#                            {'administrative-state': 'UNLOCKED',
#                             'layer-protocol-name': 'PHOTONIC_MEDIA',
#                             'lifecycle-state': 'INSTALLED',
#                             'link-port-direction': 'BIDIRECTIONAL',
#                             'mapped-service-interface-point': [],
#                             'name': [{'value': '/ne=172.20.143.64/pt=OL-2',
#                                       'value-name': 'INVENTORY_ID'},
#                                      {'value': 'NODE66/OL-2',
#                                       'value-name': 'USER'},
#                                      {'value': '172.20.143.64/OL-2',
#                                       'value-name': 'SYSTEM'}],
#                             'operational-state': 'ENABLED',
#                             'supported-cep-layer-protocol-qualifier': ['tapi-photonic-media:PHOTONIC_LAYER_QUALIFIER_OTS'],
#                             'tapi-connectivity:cep-list': {'connection-end-point': [{'client-node-edge-point': [],
#                                                                                      'connection-port-direction': 'BIDIRECTIONAL',
#                                                                                      'layer-protocol-name': 'PHOTONIC_MEDIA',
#                                                                                      'layer-protocol-qualifier': 'tapi-photonic-media:PHOTONIC_LAYER_QUALIFIER_OTS',
#                                                                                      'lifecycle-state': 'INSTALLED',
#                                                                                      'name': [{'value': '/ne=172.20.143.64/pt=OL-2',
#                                                                                                'value-name': 'INVENTORY_ID'},
#                                                                                               {'value': 'NODE66/OL-2',
#                                                                                                'value-name': 'USER'},
#                                                                                               {'value': '172.20.143.64/OL-2',
#                                                                                                'value-name': 'SYSTEM'}],
#                                                                                      'operational-state': 'ENABLED',
#                                                                                      'parent-node-edge-point': {'node-edge-point-uuid': '30000040-0000-0000-0000-000000047618',
#                                                                                                                 'node-uuid': '00000030-0000-0000-0000-000000047277',
#                                                                                                                 'topology-uuid': '00000020-0000-0000-0000-000000000003'},
#                                                                                      'tapi-adva:adva-connection-end-point-spec': {},
#                                                                                      'termination-state': 'LT_PERMENANTLY_TERMINATED',
#                                                                                      'uuid': '30000050-0000-0000-0000-000000047618'}]},
#                             'termination-direction': 'BIDIRECTIONAL',
#                             'termination-state': 'LT_PERMENANTLY_TERMINATED',
#                             'uuid': '30000040-0000-0000-0000-000000047618'},
#                            {'administrative-state': 'UNLOCKED',
#                             'layer-protocol-name': 'PHOTONIC_MEDIA',
#                             'lifecycle-state': 'INSTALLED',
#                             'link-port-direction': 'BIDIRECTIONAL',
#                             'mapped-service-interface-point': [],
#                             'name': [{'value': '/ne=172.20.143.64/pt=OL-3',
#                                       'value-name': 'INVENTORY_ID'},
#                                      {'value': 'NODE66/OL-3',
#                                       'value-name': 'USER'},
#                                      {'value': '172.20.143.64/OL-3',
#                                       'value-name': 'SYSTEM'}],
#                             'operational-state': 'ENABLED',
#                             'supported-cep-layer-protocol-qualifier': ['tapi-photonic-media:PHOTONIC_LAYER_QUALIFIER_OTS'],
#                             'tapi-connectivity:cep-list': {'connection-end-point': [{'client-node-edge-point': [],
#                                                                                      'connection-port-direction': 'BIDIRECTIONAL',
#                                                                                      'layer-protocol-name': 'PHOTONIC_MEDIA',
#                                                                                      'layer-protocol-qualifier': 'tapi-photonic-media:PHOTONIC_LAYER_QUALIFIER_OTS',
#                                                                                      'lifecycle-state': 'INSTALLED',
#                                                                                      'name': [{'value': '/ne=172.20.143.64/pt=OL-3',
#                                                                                                'value-name': 'INVENTORY_ID'},
#                                                                                               {'value': 'NODE66/OL-3',
#                                                                                                'value-name': 'USER'},
#                                                                                               {'value': '172.20.143.64/OL-3',
#                                                                                                'value-name': 'SYSTEM'}],
#                                                                                      'operational-state': 'ENABLED',
#                                                                                      'parent-node-edge-point': {'node-edge-point-uuid': '30000040-0000-0000-0000-000000047624',
#                                                                                                                 'node-uuid': '00000030-0000-0000-0000-000000047277',
#                                                                                                                 'topology-uuid': '00000020-0000-0000-0000-000000000003'},
#                                                                                      'tapi-adva:adva-connection-end-point-spec': {},
#                                                                                      'termination-state': 'LT_PERMENANTLY_TERMINATED',
#                                                                                      'uuid': '30000050-0000-0000-0000-000000047624'}]},
#                             'termination-direction': 'BIDIRECTIONAL',
#                             'termination-state': 'LT_PERMENANTLY_TERMINATED',
#                             'uuid': '30000040-0000-0000-0000-000000047624'},
#                            {'administrative-state': 'UNLOCKED',
#                             'layer-protocol-name': 'PHOTONIC_MEDIA',
#                             'lifecycle-state': 'INSTALLED',
#                             'link-port-direction': 'BIDIRECTIONAL',
#                             'mapped-service-interface-point': [],
#                             'name': [{'value': '/ne=172.20.143.64/pt=OL-1',
#                                       'value-name': 'INVENTORY_ID'},
#                                      {'value': 'NODE66/OL-1',
#                                       'value-name': 'USER'},
#                                      {'value': '172.20.143.64/OL-1',
#                                       'value-name': 'SYSTEM'}],
#                             'operational-state': 'ENABLED',
#                             'supported-cep-layer-protocol-qualifier': ['tapi-photonic-media:PHOTONIC_LAYER_QUALIFIER_OTS'],
#                             'tapi-connectivity:cep-list': {'connection-end-point': [{'client-node-edge-point': [],
#                                                                                      'connection-port-direction': 'BIDIRECTIONAL',
#                                                                                      'layer-protocol-name': 'PHOTONIC_MEDIA',
#                                                                                      'layer-protocol-qualifier': 'tapi-photonic-media:PHOTONIC_LAYER_QUALIFIER_OTS',
#                                                                                      'lifecycle-state': 'INSTALLED',
#                                                                                      'name': [{'value': '/ne=172.20.143.64/pt=OL-1',
#                                                                                                'value-name': 'INVENTORY_ID'},
#                                                                                               {'value': 'NODE66/OL-1',
#                                                                                                'value-name': 'USER'},
#                                                                                               {'value': '172.20.143.64/OL-1',
#                                                                                                'value-name': 'SYSTEM'}],
#                                                                                      'operational-state': 'ENABLED',
#                                                                                      'parent-node-edge-point': {'node-edge-point-uuid': '30000040-0000-0000-0000-000000047627',
#                                                                                                                 'node-uuid': '00000030-0000-0000-0000-000000047277',
#                                                                                                                 'topology-uuid': '00000020-0000-0000-0000-000000000003'},
#                                                                                      'tapi-adva:adva-connection-end-point-spec': {},
#                                                                                      'termination-state': 'LT_PERMENANTLY_TERMINATED',
#                                                                                      'uuid': '30000050-0000-0000-0000-000000047627'}]},
#                             'termination-direction': 'BIDIRECTIONAL',
#                             'termination-state': 'LT_PERMENANTLY_TERMINATED',
#                             'uuid': '30000040-0000-0000-0000-000000047627'},
#                            {'administrative-state': 'UNLOCKED',
#                             'layer-protocol-name': 'PHOTONIC_MEDIA',
#                             'lifecycle-state': 'INSTALLED',
#                             'link-port-direction': 'BIDIRECTIONAL',
#                             'mapped-service-interface-point': [],
#                             'name': [{'value': '/ne=172.20.143.64/sh=2/sl=14/pt=N',
#                                       'value-name': 'INVENTORY_ID'},
#                                      {'value': 'NODE66/2-14-N',
#                                       'value-name': 'USER'},
#                                      {'value': '172.20.143.64/OM-2-14-N',
#                                       'value-name': 'SYSTEM'}],
#                             'operational-state': 'DISABLED',
#                             'supported-cep-layer-protocol-qualifier': ['tapi-photonic-media:PHOTONIC_LAYER_QUALIFIER_OTS'],
#                             'tapi-connectivity:cep-list': {'connection-end-point': [{'client-node-edge-point': [{'node-edge-point-uuid': '30010040-0000-0000-0000-000000047423',
#                                                                                                                  'node-uuid': '00000030-0000-0000-0000-000000047277',
#                                                                                                                  'topology-uuid': '00000020-0000-0000-0000-000000000003'}],
#                                                                                      'connection-port-direction': 'BIDIRECTIONAL',
#                                                                                      'layer-protocol-name': 'PHOTONIC_MEDIA',
#                                                                                      'layer-protocol-qualifier': 'tapi-photonic-media:PHOTONIC_LAYER_QUALIFIER_OTS',
#                                                                                      'lifecycle-state': 'INSTALLED',
#                                                                                      'name': [{'value': '/ne=172.20.143.64/sh=2/sl=14/pt=N',
#                                                                                                'value-name': 'INVENTORY_ID'},
#                                                                                               {'value': 'NODE66/2-14-N',
#                                                                                                'value-name': 'USER'},
#                                                                                               {'value': '172.20.143.64/OM-2-14-N',
#                                                                                                'value-name': 'SYSTEM'}],
#                                                                                      'operational-state': 'DISABLED',
#                                                                                      'parent-node-edge-point': {'node-edge-point-uuid': '30000040-0000-0000-0000-000000047423',
#                                                                                                                 'node-uuid': '00000030-0000-0000-0000-000000047277',
#                                                                                                                 'topology-uuid': '00000020-0000-0000-0000-000000000003'},
#                                                                                      'tapi-adva:adva-connection-end-point-spec': {},
#                                                                                      'termination-state': 'LT_PERMENANTLY_TERMINATED',
#                                                                                      'uuid': '30000050-0000-0000-0000-000000047423'}]},
#                             'termination-direction': 'BIDIRECTIONAL',
#                             'termination-state': 'LT_PERMENANTLY_TERMINATED',
#                             'uuid': '30000040-0000-0000-0000-000000047423'},
#                            {'administrative-state': 'UNLOCKED',
#                             'layer-protocol-name': 'PHOTONIC_MEDIA',
#                             'lifecycle-state': 'INSTALLED',
#                             'link-port-direction': 'BIDIRECTIONAL',
#                             'mapped-service-interface-point': [],
#                             'name': [{'value': '/ne=172.20.143.64/sh=2/sl=10/pt=N',
#                                       'value-name': 'INVENTORY_ID'},
#                                      {'value': 'NODE66/2-10-N',
#                                       'value-name': 'USER'},
#                                      {'value': '172.20.143.64/OM-2-10-N',
#                                       'value-name': 'SYSTEM'}],
#                             'operational-state': 'DISABLED',
#                             'supported-cep-layer-protocol-qualifier': ['tapi-photonic-media:PHOTONIC_LAYER_QUALIFIER_OTS'],
#                             'tapi-connectivity:cep-list': {'connection-end-point': [{'client-node-edge-point': [{'node-edge-point-uuid': '30010040-0000-0000-0000-000000047314',
#                                                                                                                  'node-uuid': '00000030-0000-0000-0000-000000047277',
#                                                                                                                  'topology-uuid': '00000020-0000-0000-0000-000000000003'}],
#                                                                                      'connection-port-direction': 'BIDIRECTIONAL',
#                                                                                      'layer-protocol-name': 'PHOTONIC_MEDIA',
#                                                                                      'layer-protocol-qualifier': 'tapi-photonic-media:PHOTONIC_LAYER_QUALIFIER_OTS',
#                                                                                      'lifecycle-state': 'INSTALLED',
#                                                                                      'name': [{'value': '/ne=172.20.143.64/sh=2/sl=10/pt=N',
#                                                                                                'value-name': 'INVENTORY_ID'},
#                                                                                               {'value': 'NODE66/2-10-N',
#                                                                                                'value-name': 'USER'},
#                                                                                               {'value': '172.20.143.64/OM-2-10-N',
#                                                                                                'value-name': 'SYSTEM'}],
#                                                                                      'operational-state': 'DISABLED',
#                                                                                      'parent-node-edge-point': {'node-edge-point-uuid': '30000040-0000-0000-0000-000000047314',
#                                                                                                                 'node-uuid': '00000030-0000-0000-0000-000000047277',
#                                                                                                                 'topology-uuid': '00000020-0000-0000-0000-000000000003'},
#                                                                                      'tapi-adva:adva-connection-end-point-spec': {},
#                                                                                      'termination-state': 'LT_PERMENANTLY_TERMINATED',
#                                                                                      'uuid': '30000050-0000-0000-0000-000000047314'}]},
#                             'termination-direction': 'BIDIRECTIONAL',
#                             'termination-state': 'LT_PERMENANTLY_TERMINATED',
#                             'uuid': '30000040-0000-0000-0000-000000047314'},
#                            {'administrative-state': 'UNLOCKED',
#                             'layer-protocol-name': 'PHOTONIC_MEDIA',
#                             'lifecycle-state': 'INSTALLED',
#                             'link-port-direction': 'BIDIRECTIONAL',
#                             'mapped-service-interface-point': [],
#                             'name': [{'value': '/ne=172.20.143.64/sh=2/sl=12/pt=N',
#                                       'value-name': 'INVENTORY_ID'},
#                                      {'value': 'NODE66/2-12-N',
#                                       'value-name': 'USER'},
#                                      {'value': '172.20.143.64/OM-2-12-N',
#                                       'value-name': 'SYSTEM'}],
#                             'operational-state': 'DISABLED',
#                             'supported-cep-layer-protocol-qualifier': ['tapi-photonic-media:PHOTONIC_LAYER_QUALIFIER_OTS'],
#                             'tapi-connectivity:cep-list': {'connection-end-point': [{'client-node-edge-point': [{'node-edge-point-uuid': '30010040-0000-0000-0000-000000047378',
#                                                                                                                  'node-uuid': '00000030-0000-0000-0000-000000047277',
#                                                                                                                  'topology-uuid': '00000020-0000-0000-0000-000000000003'}],
#                                                                                      'connection-port-direction': 'BIDIRECTIONAL',
#                                                                                      'layer-protocol-name': 'PHOTONIC_MEDIA',
#                                                                                      'layer-protocol-qualifier': 'tapi-photonic-media:PHOTONIC_LAYER_QUALIFIER_OTS',
#                                                                                      'lifecycle-state': 'INSTALLED',
#                                                                                      'name': [{'value': '/ne=172.20.143.64/sh=2/sl=12/pt=N',
#                                                                                                'value-name': 'INVENTORY_ID'},
#                                                                                               {'value': 'NODE66/2-12-N',
#                                                                                                'value-name': 'USER'},
#                                                                                               {'value': '172.20.143.64/OM-2-12-N',
#                                                                                                'value-name': 'SYSTEM'}],
#                                                                                      'operational-state': 'DISABLED',
#                                                                                      'parent-node-edge-point': {'node-edge-point-uuid': '30000040-0000-0000-0000-000000047378',
#                                                                                                                 'node-uuid': '00000030-0000-0000-0000-000000047277',
#                                                                                                                 'topology-uuid': '00000020-0000-0000-0000-000000000003'},
#                                                                                      'tapi-adva:adva-connection-end-point-spec': {},
#                                                                                      'termination-state': 'LT_PERMENANTLY_TERMINATED',
#                                                                                      'uuid': '30000050-0000-0000-0000-000000047378'}]},
#                             'termination-direction': 'BIDIRECTIONAL',
#                             'termination-state': 'LT_PERMENANTLY_TERMINATED',
#                             'uuid': '30000040-0000-0000-0000-000000047378'},
#                            {'administrative-state': 'UNLOCKED',
#                             'layer-protocol-name': 'PHOTONIC_MEDIA',
#                             'lifecycle-state': 'INSTALLED',
#                             'link-port-direction': 'BIDIRECTIONAL',
#                             'mapped-service-interface-point': [],
#                             'name': [{'value': '/ne=172.20.143.64/sh=2/sl=12/pt=N',
#                                       'value-name': 'INVENTORY_ID'},
#                                      {'value': 'NODE66/2-12-N',
#                                       'value-name': 'USER'},
#                                      {'value': '172.20.143.64/OM-2-12-N',
#                                       'value-name': 'SYSTEM'}],
#                             'operational-state': 'DISABLED',
#                             'supported-cep-layer-protocol-qualifier': ['tapi-photonic-media:PHOTONIC_LAYER_QUALIFIER_OMS'],
#                             'tapi-connectivity:cep-list': {'connection-end-point': [{'client-node-edge-point': [],
#                                                                                      'connection-port-direction': 'BIDIRECTIONAL',
#                                                                                      'layer-protocol-name': 'PHOTONIC_MEDIA',
#                                                                                      'layer-protocol-qualifier': 'tapi-photonic-media:PHOTONIC_LAYER_QUALIFIER_OMS',
#                                                                                      'lifecycle-state': 'INSTALLED',
#                                                                                      'name': [{'value': '/ne=172.20.143.64/sh=2/sl=12/pt=N',
#                                                                                                'value-name': 'INVENTORY_ID'},
#                                                                                               {'value': 'NODE66/2-12-N',
#                                                                                                'value-name': 'USER'},
#                                                                                               {'value': '172.20.143.64/OM-2-12-N',
#                                                                                                'value-name': 'SYSTEM'}],
#                                                                                      'operational-state': 'DISABLED',
#                                                                                      'parent-node-edge-point': {'node-edge-point-uuid': '30010040-0000-0000-0000-000000047378',
#                                                                                                                 'node-uuid': '00000030-0000-0000-0000-000000047277',
#                                                                                                                 'topology-uuid': '00000020-0000-0000-0000-000000000003'},
#                                                                                      'tapi-adva:adva-connection-end-point-spec': {},
#                                                                                      'termination-state': 'LT_PERMENANTLY_TERMINATED',
#                                                                                      'uuid': '30010050-0000-0000-0000-000000047378'}]},
#                             'termination-direction': 'BIDIRECTIONAL',
#                             'termination-state': 'LT_PERMENANTLY_TERMINATED',
#                             'uuid': '30010040-0000-0000-0000-000000047378'},
#                            {'administrative-state': 'UNLOCKED',
#                             'layer-protocol-name': 'PHOTONIC_MEDIA',
#                             'lifecycle-state': 'INSTALLED',
#                             'link-port-direction': 'BIDIRECTIONAL',
#                             'mapped-service-interface-point': [],
#                             'name': [{'value': '/ne=172.20.143.64/sh=2/sl=14/pt=N',
#                                       'value-name': 'INVENTORY_ID'},
#                                      {'value': 'NODE66/2-14-N',
#                                       'value-name': 'USER'},
#                                      {'value': '172.20.143.64/OM-2-14-N',
#                                       'value-name': 'SYSTEM'}],
#                             'operational-state': 'DISABLED',
#                             'supported-cep-layer-protocol-qualifier': ['tapi-photonic-media:PHOTONIC_LAYER_QUALIFIER_OMS'],
#                             'tapi-connectivity:cep-list': {'connection-end-point': [{'client-node-edge-point': [],
#                                                                                      'connection-port-direction': 'BIDIRECTIONAL',
#                                                                                      'layer-protocol-name': 'PHOTONIC_MEDIA',
#                                                                                      'layer-protocol-qualifier': 'tapi-photonic-media:PHOTONIC_LAYER_QUALIFIER_OMS',
#                                                                                      'lifecycle-state': 'INSTALLED',
#                                                                                      'name': [{'value': '/ne=172.20.143.64/sh=2/sl=14/pt=N',
#                                                                                                'value-name': 'INVENTORY_ID'},
#                                                                                               {'value': 'NODE66/2-14-N',
#                                                                                                'value-name': 'USER'},
#                                                                                               {'value': '172.20.143.64/OM-2-14-N',
#                                                                                                'value-name': 'SYSTEM'}],
#                                                                                      'operational-state': 'DISABLED',
#                                                                                      'parent-node-edge-point': {'node-edge-point-uuid': '30010040-0000-0000-0000-000000047423',
#                                                                                                                 'node-uuid': '00000030-0000-0000-0000-000000047277',
#                                                                                                                 'topology-uuid': '00000020-0000-0000-0000-000000000003'},
#                                                                                      'tapi-adva:adva-connection-end-point-spec': {},
#                                                                                      'termination-state': 'LT_PERMENANTLY_TERMINATED',
#                                                                                      'uuid': '30010050-0000-0000-0000-000000047423'}]},
#                             'termination-direction': 'BIDIRECTIONAL',
#                             'termination-state': 'LT_PERMENANTLY_TERMINATED',
#                             'uuid': '30010040-0000-0000-0000-000000047423'},
#                            {'administrative-state': 'UNLOCKED',
#                             'layer-protocol-name': 'PHOTONIC_MEDIA',
#                             'lifecycle-state': 'INSTALLED',
#                             'link-port-direction': 'BIDIRECTIONAL',
#                             'mapped-service-interface-point': [],
#                             'name': [{'value': '/ne=172.20.143.64/sh=2/sl=10/pt=N',
#                                       'value-name': 'INVENTORY_ID'},
#                                      {'value': 'NODE66/2-10-N',
#                                       'value-name': 'USER'},
#                                      {'value': '172.20.143.64/OM-2-10-N',
#                                       'value-name': 'SYSTEM'}],
#                             'operational-state': 'DISABLED',
#                             'supported-cep-layer-protocol-qualifier': ['tapi-photonic-media:PHOTONIC_LAYER_QUALIFIER_OMS'],
#                             'tapi-connectivity:cep-list': {'connection-end-point': [{'client-node-edge-point': [],
#                                                                                      'connection-port-direction': 'BIDIRECTIONAL',
#                                                                                      'layer-protocol-name': 'PHOTONIC_MEDIA',
#                                                                                      'layer-protocol-qualifier': 'tapi-photonic-media:PHOTONIC_LAYER_QUALIFIER_OMS',
#                                                                                      'lifecycle-state': 'INSTALLED',
#                                                                                      'name': [{'value': '/ne=172.20.143.64/sh=2/sl=10/pt=N',
#                                                                                                'value-name': 'INVENTORY_ID'},
#                                                                                               {'value': 'NODE66/2-10-N',
#                                                                                                'value-name': 'USER'},
#                                                                                               {'value': '172.20.143.64/OM-2-10-N',
#                                                                                                'value-name': 'SYSTEM'}],
#                                                                                      'operational-state': 'DISABLED',
#                                                                                      'parent-node-edge-point': {'node-edge-point-uuid': '30010040-0000-0000-0000-000000047314',
#                                                                                                                 'node-uuid': '00000030-0000-0000-0000-000000047277',
#                                                                                                                 'topology-uuid': '00000020-0000-0000-0000-000000000003'},
#                                                                                      'tapi-adva:adva-connection-end-point-spec': {},
#                                                                                      'termination-state': 'LT_PERMENANTLY_TERMINATED',
#                                                                                      'uuid': '30010050-0000-0000-0000-000000047314'}]},
#                             'termination-direction': 'BIDIRECTIONAL',
#                             'termination-state': 'LT_PERMENANTLY_TERMINATED',
# ...
#                                                                                      'uuid': '30010050-0000-0000-0000-000000047289'}]},
#                             'termination-direction': 'BIDIRECTIONAL',
#                             'termination-state': 'LT_PERMENANTLY_TERMINATED',
#                             'uuid': '30010040-0000-0000-0000-000000047289'},
#                            {'administrative-state': 'UNLOCKED',
#                             'layer-protocol-name': 'PHOTONIC_MEDIA',
#                             'lifecycle-state': 'INSTALLED',
#                             'link-port-direction': 'BIDIRECTIONAL',
#                             'mapped-service-interface-point': [],
#                             'name': [{'value': '/ne=172.20.143.64/sh=2/sl=4/pt=N',
#                                       'value-name': 'INVENTORY_ID'},
#                                      {'value': 'NODE66/2-4-N',
#                                       'value-name': 'USER'},
#                                      {'value': '172.20.143.64/OM-2-4-N',
#                                       'value-name': 'SYSTEM'}],
#                             'operational-state': 'DISABLED',
#                             'supported-cep-layer-protocol-qualifier': ['tapi-photonic-media:PHOTONIC_LAYER_QUALIFIER_OMS'],
#                             'tapi-connectivity:cep-list': {'connection-end-point': [{'client-node-edge-point': [{'node-edge-point-uuid': '30040040-0000-0000-0000-000000047555',
#                                                                                                                  'node-uuid': '00000030-0000-0000-0000-000000047277',
#                                                                                                                  'topology-uuid': '00000020-0000-0000-0000-000000000003'}],
#                                                                                      'connection-port-direction': 'BIDIRECTIONAL',
#                                                                                      'layer-protocol-name': 'PHOTONIC_MEDIA',
#                                                                                      'layer-protocol-qualifier': 'tapi-photonic-media:PHOTONIC_LAYER_QUALIFIER_OMS',
#                                                                                      'lifecycle-state': 'INSTALLED',
#                                                                                      'name': [{'value': '/ne=172.20.143.64/sh=2/sl=4/pt=N',
#                                                                                                'value-name': 'INVENTORY_ID'},
#                                                                                               {'value': 'NODE66/2-4-N',
#                                                                                                'value-name': 'USER'},
#                                                                                               {'value': '172.20.143.64/OM-2-4-N',
#                                                                                                'value-name': 'SYSTEM'}],
#                                                                                      'operational-state': 'DISABLED',
#                                                                                      'parent-node-edge-point': {'node-edge-point-uuid': '30010040-0000-0000-0000-000000047555',
#                                                                                                                 'node-uuid': '00000030-0000-0000-0000-000000047277',
#                                                                                                                 'topology-uuid': '00000020-0000-0000-0000-000000000003'},
#                                                                                      'tapi-adva:adva-connection-end-point-spec': {},
#                                                                                      'termination-state': 'LT_PERMENANTLY_TERMINATED',
#                                                                                      'uuid': '30010050-0000-0000-0000-000000047555'}]},
#                             'termination-direction': 'BIDIRECTIONAL',
#                             'termination-state': 'LT_PERMENANTLY_TERMINATED',
#                             'uuid': '30010040-0000-0000-0000-000000047555'},
#                            {'administrative-state': 'UNLOCKED',
#                             'layer-protocol-name': 'PHOTONIC_MEDIA',
#                             'lifecycle-state': 'INSTALLED',
#                             'link-port-direction': 'BIDIRECTIONAL',
#                             'mapped-service-interface-point': [],
#                             'name': [{'value': '/ne=172.20.143.64/sh=2/sl=7/pt=N',
#                                       'value-name': 'INVENTORY_ID'},
#                                      {'value': 'NODE66/2-7-N',
#                                       'value-name': 'USER'},
#                                      {'value': '172.20.143.64/OM-2-7-N',
#                                       'value-name': 'SYSTEM'}],
#                             'operational-state': 'DISABLED',
#                             'supported-cep-layer-protocol-qualifier': ['tapi-photonic-media:PHOTONIC_LAYER_QUALIFIER_OCH'],
#                             'tapi-connectivity:cep-list': {'connection-end-point': []},
#                             'tapi-photonic-media:media-channel-node-edge-point-spec': {'mc-pool': {'available-spectrum': [{'frequency-constraint': {'adjustment-granularity': 'G_50GHZ',
#                                                                                                                                                     'grid-type': 'DWDM'},
#                                                                                                                            'lower-frequency': '191212500',
#                                                                                                                            'upper-frequency': '196125000'}],
#                                                                                                    'occupied-spectrum': [],
#                                                                                                    'supportable-spectrum': [{'frequency-constraint': {'adjustment-granularity': 'G_50GHZ',
#                                                                                                                                                       'grid-type': 'DWDM'},
#                                                                                                                              'lower-frequency': '191212500',
#                                                                                                                              'upper-frequency': '196125000'}]}},
#                             'termination-direction': 'BIDIRECTIONAL',
#                             'termination-state': 'TERMINATED_BIDIRECTIONAL',
#                             'uuid': '30040040-0000-0000-0000-000000047567'},
#                            {'administrative-state': 'UNLOCKED',
#                             'layer-protocol-name': 'PHOTONIC_MEDIA',
#                             'lifecycle-state': 'INSTALLED',
#                             'link-port-direction': 'BIDIRECTIONAL',
#                             'mapped-service-interface-point': [],
#                             'name': [{'value': '/ne=172.20.143.64/sh=2/sl=1/pt=N',
#                                       'value-name': 'INVENTORY_ID'},
#                                      {'value': 'NODE66/2-1-N',
#                                       'value-name': 'USER'},
#                                      {'value': '172.20.143.64/OM-2-1-N',
#                                       'value-name': 'SYSTEM'}],
#                             'operational-state': 'DISABLED',
#                             'supported-cep-layer-protocol-qualifier': ['tapi-photonic-media:PHOTONIC_LAYER_QUALIFIER_OCH'],
#                             'tapi-connectivity:cep-list': {'connection-end-point': []},
#                             'tapi-photonic-media:media-channel-node-edge-point-spec': {'mc-pool': {'available-spectrum': [{'frequency-constraint': {'adjustment-granularity': 'G_50GHZ',
#                                                                                                                                                     'grid-type': 'DWDM'},
#                                                                                                                            'lower-frequency': '191212500',
#                                                                                                                            'upper-frequency': '196125000'}],
#                                                                                                    'occupied-spectrum': [],
#                                                                                                    'supportable-spectrum': [{'frequency-constraint': {'adjustment-granularity': 'G_50GHZ',
#                                                                                                                                                       'grid-type': 'DWDM'},
#                                                                                                                              'lower-frequency': '191212500',
#                                                                                                                              'upper-frequency': '196125000'}]}},
#                             'termination-direction': 'BIDIRECTIONAL',
#                             'termination-state': 'TERMINATED_BIDIRECTIONAL',
#                             'uuid': '30040040-0000-0000-0000-000000047289'},
#                            {'administrative-state': 'UNLOCKED',
#                             'layer-protocol-name': 'PHOTONIC_MEDIA',
#                             'lifecycle-state': 'INSTALLED',
#                             'link-port-direction': 'BIDIRECTIONAL',
#                             'mapped-service-interface-point': [],
#                             'name': [{'value': '/ne=172.20.143.64/sh=2/sl=4/pt=N',
#                                       'value-name': 'INVENTORY_ID'},
#                                      {'value': 'NODE66/2-4-N',
#                                       'value-name': 'USER'},
#                                      {'value': '172.20.143.64/OM-2-4-N',
#                                       'value-name': 'SYSTEM'}],
#                             'operational-state': 'DISABLED',
#                             'supported-cep-layer-protocol-qualifier': ['tapi-photonic-media:PHOTONIC_LAYER_QUALIFIER_OCH'],
#                             'tapi-connectivity:cep-list': {'connection-end-point': []},
#                             'tapi-photonic-media:media-channel-node-edge-point-spec': {'mc-pool': {'available-spectrum': [{'frequency-constraint': {'adjustment-granularity': 'G_50GHZ',
#                                                                                                                                                     'grid-type': 'DWDM'},
#                                                                                                                            'lower-frequency': '191212500',
#                                                                                                                            'upper-frequency': '196125000'}],
#                                                                                                    'occupied-spectrum': [],
#                                                                                                    'supportable-spectrum': [{'frequency-constraint': {'adjustment-granularity': 'G_50GHZ',
#                                                                                                                                                       'grid-type': 'DWDM'},
#                                                                                                                              'lower-frequency': '191212500',
#                                                                                                                              'upper-frequency': '196125000'}]}},
#                             'termination-direction': 'BIDIRECTIONAL',
#                             'termination-state': 'TERMINATED_BIDIRECTIONAL',
#                             'uuid': '30040040-0000-0000-0000-000000047555'},
#                            {'administrative-state': 'LOCKED',
#                             'layer-protocol-name': 'PHOTONIC_MEDIA',
#                             'lifecycle-state': 'PLANNED',
#                             'link-port-direction': 'BIDIRECTIONAL',
#                             'mapped-service-interface-point': [{'service-interface-point-uuid': '00000010-0000-0000-0000-000000047587'}],
#                             'name': [{'value': '/ne=172.20.143.64/sh=3/sl=1/pt=N',
#                                       'value-name': 'INVENTORY_ID'},
#                                      {'value': 'NODE66/3-1-N',
#                                       'value-name': 'USER'},
#                                      {'value': '172.20.143.64/PTP-3-1-N',
#                                       'value-name': 'SYSTEM'}],
#                             'operational-state': 'DISABLED',
#                             'supported-cep-layer-protocol-qualifier': ['tapi-photonic-media:PHOTONIC_LAYER_QUALIFIER_OCH'],
#                             'tapi-connectivity:cep-list': {'connection-end-point': []},
#                             'tapi-photonic-media:media-channel-node-edge-point-spec': {'mc-pool': {'available-spectrum': [],
#                                                                                                    'occupied-spectrum': [],
#                                                                                                    'supportable-spectrum': []}},
#                             'termination-direction': 'BIDIRECTIONAL',
#                             'termination-state': 'TERMINATED_BIDIRECTIONAL',
#                             'uuid': '30040040-0000-0000-0000-000000047587'},
#                            {'administrative-state': 'LOCKED',
#                             'layer-protocol-name': 'DSR',
#                             'lifecycle-state': 'PLANNED',
#                             'link-port-direction': 'BIDIRECTIONAL',
#                             'mapped-service-interface-point': [{'service-interface-point-uuid': '00000010-0000-0000-0000-000000047587'}],
#                             'name': [{'value': '/ne=172.20.143.64/sh=3/sl=1/pt=N',
#                                       'value-name': 'INVENTORY_ID'},
#                                      {'value': 'NODE66/3-1-N',
#                                       'value-name': 'USER'},
#                                      {'value': '172.20.143.64/PTP-3-1-N',
#                                       'value-name': 'SYSTEM'}],
#                             'operational-state': 'DISABLED',
#                             'supported-cep-layer-protocol-qualifier': ['tapi-dsr:DIGITAL_SIGNAL_TYPE_100_GigE'],
#                             'tapi-connectivity:cep-list': {'connection-end-point': []},
#                             'termination-direction': 'BIDIRECTIONAL',
#                             'termination-state': 'TERMINATED_BIDIRECTIONAL',
#                             'uuid': '20000040-0000-0000-0000-000000047587'}],
#  'tapi-adva:adva-node-spec': {'adva-administrative-state': 'IN_SERVICE',
#                               'cp-mode': 'CPD',
#                               'ip-address': '172.20.143.64',
#                               'ne-type': 'FSP 3000R7',
#                               'reachability-status': 'REACHABLE',
#                               'serial-number': '',
#                               'sw-version': '20.3.1',
#                               'user-label': 'NODE66'},
#  'uuid': '00000030-0000-0000-0000-000000047277'}

# %%
for node in context["tapi-common:context"]["tapi-topology:topology-context"]["topology"][0]["node"]:
    print(node["name"][0]["value"])
    print(node["uuid"])
# Out:
# NODE66
# 00000030-0000-0000-0000-000000047277
# NODE70.1
# 00000030-0000-0000-0000-000000048451
# NODE62.1
# 00000030-0000-0000-0000-000000045888
# NODE64
# 00000030-0000-0000-0000-000000045758

# %%
for link in context["tapi-common:context"]["tapi-topology:topology-context"]["topology"][0]["link"]:
    print(link["uuid"])
    print("\t", link["node-edge-point"][0]["node-edge-point-uuid"])
# Out:
# 30000060-0000-0000-0000-000000048794
# 30000040-0000-0000-0000-000000048730
# 30040060-0000-0000-0000-000000046570
# 30040040-0000-0000-0000-000000046072
# 30000060-0000-0000-0000-000000048799
# 30000040-0000-0000-0000-000000048721
# 30000060-0000-0000-0000-000000046544
# 30000040-0000-0000-0000-000000046457
# 30040060-0000-0000-0000-000000047743
# 30040040-0000-0000-0000-000000046303
# 30000060-0000-0000-0000-000000047714
# 30000040-0000-0000-0000-000000047618
# 30040060-0000-0000-0000-000000047767
# 30040040-0000-0000-0000-000000045772
# 30040060-0000-0000-0000-000000048823
# 30040040-0000-0000-0000-000000047289
# 30000060-0000-0000-0000-000000047719
# 30000040-0000-0000-0000-000000047624
# 30010060-0000-0000-0000-000000047731
# 30010040-0000-0000-0000-000000047378
# 30040060-0000-0000-0000-000000048847
# 30040040-0000-0000-0000-000000045917
# 30010060-0000-0000-0000-000000047755
# 30010040-0000-0000-0000-000000047423
# 30010060-0000-0000-0000-000000048811
# 30010040-0000-0000-0000-000000048488
# 30010060-0000-0000-0000-000000046557
# 30010040-0000-0000-0000-000000046171
# 30010060-0000-0000-0000-000000048835
# 30010040-0000-0000-0000-000000048552

# %%
link = requests.get(
    "https://localhost:8082/restconf/data/tapi-common:context/tapi-topology:topology-context/topology=00000020-0000-0000-0000-000000000003/link",
    headers={
        "Authorization": "Basic YWRtaW46bm9tb3Jlc2VjcmV0"
    },
    verify=False
)
link
# Out:
# /Users/carda/projects/DefragDashboard/venv/lib/python3.10/site-packages/urllib3/connectionpool.py:1095: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# <Response [200]>

# %%
with open("link.json", "wt", encoding="UTF-8") as file:
    json.dump(link.json(), file)

# %%
node = requests.get(
    "https://localhost:8082/restconf/data/tapi-common:context/tapi-topology:topology-context/topology=00000020-0000-0000-0000-000000000003/node",
    headers={
        "Authorization": "Basic YWRtaW46bm9tb3Jlc2VjcmV0"
    },
    verify=False
)
node
pprint(node.json())

with open("node.json", "wt", encoding="UTF-8") as file:
    json.dump(node.json(), file)
# Out:
# /Users/carda/projects/DefragDashboard/venv/lib/python3.10/site-packages/urllib3/connectionpool.py:1095: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# {'tapi-topology:node': [{'cost-characteristic': [{'cost-name': 'NOT_SUPPORTED_MANDATORY_FIELD'}],
#                          'latency-characteristic': [{'traffic-property-name': 'NOT_SUPPORTED_MANDATORY_FIELD'}],
#                          'layer-protocol-name': ['PHOTONIC_MEDIA',
#                                                  'DSR',
#                                                  'ODU'],
#                          'lifecycle-state': 'INSTALLED',
#                          'name': [{'value': 'NODE66', 'value-name': 'USER'},
#                                   {'value': '172.20.143.64',
#                                    'value-name': 'SYSTEM'},
#                                   {'value': '/ne=172.20.143.64',
#                                    'value-name': 'INVENTORY_ID'}],
#                          'operational-state': 'ENABLED',
#                          'owned-node-edge-point': [{'administrative-state': 'LOCKED',
#                                                     'layer-protocol-name': 'DSR',
#                                                     'lifecycle-state': 'PLANNED',
#                                                     'link-port-direction': 'BIDIRECTIONAL',
#                                                     'mapped-service-interface-point': [{'service-interface-point-uuid': '00000010-0000-0000-0000-000000047591'}],
#                                                     'name': [{'value': '/ne=172.20.143.64/sh=3/sl=1/pt=C',
#                                                               'value-name': 'INVENTORY_ID'},
#                                                              {'value': 'NODE66/3-1-C',
#                                                               'value-name': 'USER'},
#                                                              {'value': '172.20.143.64/PTP-3-1-C',
#                                                               'value-name': 'SYSTEM'}],
#                                                     'operational-state': 'DISABLED',
#                                                     'supported-cep-layer-protocol-qualifier': ['tapi-dsr:DIGITAL_SIGNAL_TYPE_100_GigE',
#                                                                                                'tapi-dsr:DIGITAL_SIGNAL_TYPE_OTU_4'],
#                                                     'tapi-connectivity:cep-list': {'connection-end-point': [{'client-node-edge-point': [],
#                                                                                                              'connection-port-direction': 'BIDIRECTIONAL',
#                                                                                                              'layer-protocol-name': 'DSR',
#                                                                                                              'layer-protocol-qualifier': 'tapi-dsr:DIGITAL_SIGNAL_TYPE_100_GigE',
#                                                                                                              'lifecycle-state': 'PLANNED',
#                                                                                                              'name': [{'value': '/ne=172.20.143.64/sh=3/sl=1/pt=C',
#                                                                                                                        'value-name': 'INVENTORY_ID'},
#                                                                                                                       {'value': 'NODE66/3-1-C',
#                                                                                                                        'value-name': 'USER'},
#                                                                                                                       {'value': '172.20.143.64/PTP-3-1-C',
#                                                                                                                        'value-name': 'SYSTEM'}],
#                                                                                                              'operational-state': 'DISABLED',
#                                                                                                              'parent-node-edge-point': {'node-edge-point-uuid': '20000040-0000-0000-0000-000000047591',
#                                                                                                                                         'node-uuid': '00000030-0000-0000-0000-000000047277',
#                                                                                                                                         'topology-uuid': '00000020-0000-0000-0000-000000000003'},
#                                                                                                              'tapi-adva:adva-connection-end-point-spec': {},
#                                                                                                              'termination-state': 'TERMINATED_BIDIRECTIONAL',
#                                                                                                              'uuid': '20050050-0000-0000-0000-000000047591'}]},
#                                                     'termination-direction': 'BIDIRECTIONAL',
#                                                     'termination-state': 'TERMINATED_BIDIRECTIONAL',
#                                                     'uuid': '20000040-0000-0000-0000-000000047591'},
#                                                    {'administrative-state': 'LOCKED',
#                                                     'layer-protocol-name': 'ODU',
#                                                     'lifecycle-state': 'PLANNED',
#                                                     'link-port-direction': 'BIDIRECTIONAL',
#                                                     'mapped-service-interface-point': [{'service-interface-point-uuid': '00000010-0000-0000-0000-000000047587'}],
#                                                     'name': [{'value': '/ne=172.20.143.64/sh=3/sl=1/pt=N',
#                                                               'value-name': 'INVENTORY_ID'},
#                                                              {'value': 'NODE66/3-1-N',
#                                                               'value-name': 'USER'},
#                                                              {'value': '172.20.143.64/PTP-3-1-N',
#                                                               'value-name': 'SYSTEM'}],
#                                                     'operational-state': 'DISABLED',
#                                                     'supported-cep-layer-protocol-qualifier': ['tapi-odu:ODU_TYPE_ODU4'],
#                                                     'tapi-connectivity:cep-list': {'connection-end-point': [{'client-node-edge-point': [],
#                                                                                                              'connection-port-direction': 'BIDIRECTIONAL',
#                                                                                                              'layer-protocol-name': 'ODU',
#                                                                                                              'layer-protocol-qualifier': 'tapi-odu:ODU_TYPE_ODU4',
#                                                                                                              'lifecycle-state': 'PLANNED',
#                                                                                                              'name': [{'value': '/ne=172.20.143.64/sh=3/sl=1/pt=N',
#                                                                                                                        'value-name': 'INVENTORY_ID'},
#                                                                                                                       {'value': 'NODE66/3-1-N',
#                                                                                                                        'value-name': 'USER'},
#                                                                                                                       {'value': '172.20.143.64/PTP-3-1-N',
#                                                                                                                        'value-name': 'SYSTEM'}],
#                                                                                                              'operational-state': 'DISABLED',
#                                                                                                              'parent-node-edge-point': {'node-edge-point-uuid': '00060040-0000-0000-0000-000000047587',
#                                                                                                                                         'node-uuid': '00000030-0000-0000-0000-000000047277',
#                                                                                                                                         'topology-uuid': '00000020-0000-0000-0000-000000000003'},
#                                                                                                              'tapi-adva:adva-connection-end-point-spec': {},
#                                                                                                              'tapi-odu:odu-connection-end-point-spec': {'odu-common': {'odu-rate': '104794445',
#                                                                                                                                                                        'odu-rate-tolerance': '20',
#                                                                                                                                                                        'odu-type': 'tapi-odu:ODU_TYPE_ODU4'},
#                                                                                                                                                         'odu-protection': {'aps-enable': False},
#                                                                                                                                                         'odu-term-and-adapter': {'auto-payload-type': False,
#                                                                                                                                                                                  'opu-tributary-slot-size': '1G25'}},
#                                                                                                              'termination-state': 'TERMINATED_BIDIRECTIONAL',
#                                                                                                              'uuid': '00060050-0000-0000-0000-000000047587'}]},
#                                                     'tapi-odu:odu-node-edge-point-spec': {'odu-pool': {'client-capacity': '104794445'}},
#                                                     'termination-direction': 'BIDIRECTIONAL',
#                                                     'termination-state': 'TERMINATED_BIDIRECTIONAL',
#                                                     'uuid': '00060040-0000-0000-0000-000000047587'},
#                                                    {'administrative-state': 'UNLOCKED',
#                                                     'layer-protocol-name': 'DSR',
#                                                     'lifecycle-state': 'INSTALLED',
#                                                     'link-port-direction': 'BIDIRECTIONAL',
#                                                     'mapped-service-interface-point': [{'service-interface-point-uuid': '00000010-0000-0000-0000-000000047598'}],
#                                                     'name': [{'value': '/ne=172.20.143.64/sh=3/sl=3/pt=C',
#                                                               'value-name': 'INVENTORY_ID'},
#                                                              {'value': 'NODE66/3-3-C',
#                                                               'value-name': 'USER'},
#                                                              {'value': '172.20.143.64/CH-3-3-C',
#                                                               'value-name': 'SYSTEM'}],
#                                                     'operational-state': 'ENABLED',
#                                                     'supported-cep-layer-protocol-qualifier': ['tapi-dsr:DIGITAL_SIGNAL_TYPE_100_GigE',
#                                                                                                'tapi-dsr:DIGITAL_SIGNAL_TYPE_OTU_4'],
#                                                     'tapi-connectivity:cep-list': {'connection-end-point': []},
#                                                     'termination-direction': 'BIDIRECTIONAL',
#                                                     'termination-state': 'TERMINATED_BIDIRECTIONAL',
#                                                     'uuid': '20000040-0000-0000-0000-000000047598'},
#                                                    {'administrative-state': 'LOCKED',
#                                                     'layer-protocol-name': 'ODU',
#                                                     'lifecycle-state': 'PLANNED',
#                                                     'link-port-direction': 'BIDIRECTIONAL',
#                                                     'mapped-service-interface-point': [{'service-interface-point-uuid': '00000010-0000-0000-0000-000000047603'}],
#                                                     'name': [{'value': '/ne=172.20.143.64/sh=3/sl=3/pt=N',
#                                                               'value-name': 'INVENTORY_ID'},
#                                                              {'value': 'NODE66/3-3-N',
#                                                               'value-name': 'USER'},
#                                                              {'value': '172.20.143.64/PTP-3-3-N',
#                                                               'value-name': 'SYSTEM'}],
#                                                     'operational-state': 'DISABLED',
#                                                     'supported-cep-layer-protocol-qualifier': ['tapi-odu:ODU_TYPE_ODU4'],
#                                                     'tapi-connectivity:cep-list': {'connection-end-point': []},
#                                                     'tapi-odu:odu-node-edge-point-spec': {'odu-pool': {'client-capacity': '104794445'}},
#                                                     'termination-direction': 'BIDIRECTIONAL',
#                                                     'termination-state': 'TERMINATED_BIDIRECTIONAL',
#                                                     'uuid': '00060040-0000-0000-0000-000000047603'},
#                                                    {'administrative-state': 'LOCKED',
#                                                     'layer-protocol-name': 'ODU',
#                                                     'lifecycle-state': 'PLANNED',
#                                                     'link-port-direction': 'BIDIRECTIONAL',
#                                                     'mapped-service-interface-point': [{'service-interface-point-uuid': '00000010-0000-0000-0000-000000047609'}],
#                                                     'name': [{'value': '/ne=172.20.143.64/sh=3/sl=5/pt=N',
#                                                               'value-name': 'INVENTORY_ID'},
#                                                              {'value': 'NODE66/3-5-N',
#                                                               'value-name': 'USER'},
#                                                              {'value': '172.20.143.64/PTP-3-5-N',
#                                                               'value-name': 'SYSTEM'}],
#                                                     'operational-state': 'DISABLED',
#                                                     'supported-cep-layer-protocol-qualifier': ['tapi-odu:ODU_TYPE_ODU4'],
#                                                     'tapi-connectivity:cep-list': {'connection-end-point': []},
#                                                     'tapi-odu:odu-node-edge-point-spec': {'odu-pool': {'client-capacity': '104794445'}},
#                                                     'termination-direction': 'BIDIRECTIONAL',
#                                                     'termination-state': 'TERMINATED_BIDIRECTIONAL',
#                                                     'uuid': '00060040-0000-0000-0000-000000047609'},
#                                                    {'administrative-state': 'UNLOCKED',
#                                                     'layer-protocol-name': 'DSR',
#                                                     'lifecycle-state': 'INSTALLED',
#                                                     'link-port-direction': 'BIDIRECTIONAL',
#                                                     'mapped-service-interface-point': [{'service-interface-point-uuid': '00000010-0000-0000-0000-000000047613'}],
#                                                     'name': [{'value': '/ne=172.20.143.64/sh=3/sl=5/pt=C',
#                                                               'value-name': 'INVENTORY_ID'},
#                                                              {'value': 'NODE66/3-5-C',
#                                                               'value-name': 'USER'},
#                                                              {'value': '172.20.143.64/CH-3-5-C',
#                                                               'value-name': 'SYSTEM'}],
#                                                     'operational-state': 'ENABLED',
#                                                     'supported-cep-layer-protocol-qualifier': ['tapi-dsr:DIGITAL_SIGNAL_TYPE_100_GigE',
#                                                                                                'tapi-dsr:DIGITAL_SIGNAL_TYPE_OTU_4'],
#                                                     'tapi-connectivity:cep-list': {'connection-end-point': []},
#                                                     'termination-direction': 'BIDIRECTIONAL',
#                                                     'termination-state': 'TERMINATED_BIDIRECTIONAL',
#                                                     'uuid': '20000040-0000-0000-0000-000000047613'},
#                                                    {'administrative-state': 'UNLOCKED',
#                                                     'layer-protocol-name': 'PHOTONIC_MEDIA',
#                                                     'lifecycle-state': 'INSTALLED',
#                                                     'link-port-direction': 'BIDIRECTIONAL',
#                                                     'mapped-service-interface-point': [],
#                                                     'name': [{'value': '/ne=172.20.143.64/pt=OL-2',
#                                                               'value-name': 'INVENTORY_ID'},
#                                                              {'value': 'NODE66/OL-2',
#                                                               'value-name': 'USER'},
#                                                              {'value': '172.20.143.64/OL-2',
#                                                               'value-name': 'SYSTEM'}],
#                                                     'operational-state': 'ENABLED',
#                                                     'supported-cep-layer-protocol-qualifier': ['tapi-photonic-media:PHOTONIC_LAYER_QUALIFIER_OTS'],
#                                                     'tapi-connectivity:cep-list': {'connection-end-point': [{'client-node-edge-point': [],
#                                                                                                              'connection-port-direction': 'BIDIRECTIONAL',
#                                                                                                              'layer-protocol-name': 'PHOTONIC_MEDIA',
#                                                                                                              'layer-protocol-qualifier': 'tapi-photonic-media:PHOTONIC_LAYER_QUALIFIER_OTS',
#                                                                                                              'lifecycle-state': 'INSTALLED',
#                                                                                                              'name': [{'value': '/ne=172.20.143.64/pt=OL-2',
#                                                                                                                        'value-name': 'INVENTORY_ID'},
#                                                                                                                       {'value': 'NODE66/OL-2',
#                                                                                                                        'value-name': 'USER'},
#                                                                                                                       {'value': '172.20.143.64/OL-2',
#                                                                                                                        'value-name': 'SYSTEM'}],
#                                                                                                              'operational-state': 'ENABLED',
#                                                                                                              'parent-node-edge-point': {'node-edge-point-uuid': '30000040-0000-0000-0000-000000047618',
#                                                                                                                                         'node-uuid': '00000030-0000-0000-0000-000000047277',
#                                                                                                                                         'topology-uuid': '00000020-0000-0000-0000-000000000003'},
#                                                                                                              'tapi-adva:adva-connection-end-point-spec': {},
#                                                                                                              'termination-state': 'LT_PERMENANTLY_TERMINATED',
#                                                                                                              'uuid': '30000050-0000-0000-0000-000000047618'}]},
#                                                     'termination-direction': 'BIDIRECTIONAL',
#                                                     'termination-state': 'LT_PERMENANTLY_TERMINATED',
#                                                     'uuid': '30000040-0000-0000-0000-000000047618'},
#                                                    {'administrative-state': 'UNLOCKED',
#                                                     'layer-protocol-name': 'PHOTONIC_MEDIA',
#                                                     'lifecycle-state': 'INSTALLED',
#                                                     'link-port-direction': 'BIDIRECTIONAL',
#                                                     'mapped-service-interface-point': [],
#                                                     'name': [{'value': '/ne=172.20.143.64/pt=OL-3',
#                                                               'value-name': 'INVENTORY_ID'},
#                                                              {'value': 'NODE66/OL-3',
#                                                               'value-name': 'USER'},
#                                                              {'value': '172.20.143.64/OL-3',
#                                                               'value-name': 'SYSTEM'}],
#                                                     'operational-state': 'ENABLED',
#                                                     'supported-cep-layer-protocol-qualifier': ['tapi-photonic-media:PHOTONIC_LAYER_QUALIFIER_OTS'],
#                                                     'tapi-connectivity:cep-list': {'connection-end-point': [{'client-node-edge-point': [],
#                                                                                                              'connection-port-direction': 'BIDIRECTIONAL',
#                                                                                                              'layer-protocol-name': 'PHOTONIC_MEDIA',
#                                                                                                              'layer-protocol-qualifier': 'tapi-photonic-media:PHOTONIC_LAYER_QUALIFIER_OTS',
#                                                                                                              'lifecycle-state': 'INSTALLED',
#                                                                                                              'name': [{'value': '/ne=172.20.143.64/pt=OL-3',
#                                                                                                                        'value-name': 'INVENTORY_ID'},
#                                                                                                                       {'value': 'NODE66/OL-3',
#                                                                                                                        'value-name': 'USER'},
#                                                                                                                       {'value': '172.20.143.64/OL-3',
#                                                                                                                        'value-name': 'SYSTEM'}],
#                                                                                                              'operational-state': 'ENABLED',
#                                                                                                              'parent-node-edge-point': {'node-edge-point-uuid': '30000040-0000-0000-0000-000000047624',
#                                                                                                                                         'node-uuid': '00000030-0000-0000-0000-000000047277',
#                                                                                                                                         'topology-uuid': '00000020-0000-0000-0000-000000000003'},
#                                                                                                              'tapi-adva:adva-connection-end-point-spec': {},
#                                                                                                              'termination-state': 'LT_PERMENANTLY_TERMINATED',
#                                                                                                              'uuid': '30000050-0000-0000-0000-000000047624'}]},
#                                                     'termination-direction': 'BIDIRECTIONAL',
#                                                     'termination-state': 'LT_PERMENANTLY_TERMINATED',
#                                                     'uuid': '30000040-0000-0000-0000-000000047624'},
#                                                    {'administrative-state': 'UNLOCKED',
#                                                     'layer-protocol-name': 'PHOTONIC_MEDIA',
#                                                     'lifecycle-state': 'INSTALLED',
#                                                     'link-port-direction': 'BIDIRECTIONAL',
#                                                     'mapped-service-interface-point': [],
#                                                     'name': [{'value': '/ne=172.20.143.64/pt=OL-1',
#                                                               'value-name': 'INVENTORY_ID'},
#                                                              {'value': 'NODE66/OL-1',
#                                                               'value-name': 'USER'},
#                                                              {'value': '172.20.143.64/OL-1',
#                                                               'value-name': 'SYSTEM'}],
#                                                     'operational-state': 'ENABLED',
#                                                     'supported-cep-layer-protocol-qualifier': ['tapi-photonic-media:PHOTONIC_LAYER_QUALIFIER_OTS'],
#                                                     'tapi-connectivity:cep-list': {'connection-end-point': [{'client-node-edge-point': [],
#                                                                                                              'connection-port-direction': 'BIDIRECTIONAL',
#                                                                                                              'layer-protocol-name': 'PHOTONIC_MEDIA',
#                                                                                                              'layer-protocol-qualifier': 'tapi-photonic-media:PHOTONIC_LAYER_QUALIFIER_OTS',
#                                                                                                              'lifecycle-state': 'INSTALLED',
#                                                                                                              'name': [{'value': '/ne=172.20.143.64/pt=OL-1',
#                                                                                                                        'value-name': 'INVENTORY_ID'},
#                                                                                                                       {'value': 'NODE66/OL-1',
#                                                                                                                        'value-name': 'USER'},
#                                                                                                                       {'value': '172.20.143.64/OL-1',
#                                                                                                                        'value-name': 'SYSTEM'}],
#                                                                                                              'operational-state': 'ENABLED',
#                                                                                                              'parent-node-edge-point': {'node-edge-point-uuid': '30000040-0000-0000-0000-000000047627',
#                                                                                                                                         'node-uuid': '00000030-0000-0000-0000-000000047277',
#                                                                                                                                         'topology-uuid': '00000020-0000-0000-0000-000000000003'},
#                                                                                                              'tapi-adva:adva-connection-end-point-spec': {},
#                                                                                                              'termination-state': 'LT_PERMENANTLY_TERMINATED',
#                                                                                                              'uuid': '30000050-0000-0000-0000-000000047627'}]},
#                                                     'termination-direction': 'BIDIRECTIONAL',
#                                                     'termination-state': 'LT_PERMENANTLY_TERMINATED',
#                                                     'uuid': '30000040-0000-0000-0000-000000047627'},
#                                                    {'administrative-state': 'UNLOCKED',
#                                                     'layer-protocol-name': 'PHOTONIC_MEDIA',
#                                                     'lifecycle-state': 'INSTALLED',
#                                                     'link-port-direction': 'BIDIRECTIONAL',
#                                                     'mapped-service-interface-point': [],
#                                                     'name': [{'value': '/ne=172.20.143.64/sh=2/sl=14/pt=N',
#                                                               'value-name': 'INVENTORY_ID'},
#                                                              {'value': 'NODE66/2-14-N',
#                                                               'value-name': 'USER'},
#                                                              {'value': '172.20.143.64/OM-2-14-N',
#                                                               'value-name': 'SYSTEM'}],
#                                                     'operational-state': 'DISABLED',
#                                                     'supported-cep-layer-protocol-qualifier': ['tapi-photonic-media:PHOTONIC_LAYER_QUALIFIER_OTS'],
#                                                     'tapi-connectivity:cep-list': {'connection-end-point': [{'client-node-edge-point': [{'node-edge-point-uuid': '30010040-0000-0000-0000-000000047423',
#                                                                                                                                          'node-uuid': '00000030-0000-0000-0000-000000047277',
#                                                                                                                                          'topology-uuid': '00000020-0000-0000-0000-000000000003'}],
#                                                                                                              'connection-port-direction': 'BIDIRECTIONAL',
#                                                                                                              'layer-protocol-name': 'PHOTONIC_MEDIA',
#                                                                                                              'layer-protocol-qualifier': 'tapi-photonic-media:PHOTONIC_LAYER_QUALIFIER_OTS',
#                                                                                                              'lifecycle-state': 'INSTALLED',
#                                                                                                              'name': [{'value': '/ne=172.20.143.64/sh=2/sl=14/pt=N',
#                                                                                                                        'value-name': 'INVENTORY_ID'},
#                                                                                                                       {'value': 'NODE66/2-14-N',
#                                                                                                                        'value-name': 'USER'},
#                                                                                                                       {'value': '172.20.143.64/OM-2-14-N',
#                                                                                                                        'value-name': 'SYSTEM'}],
#                                                                                                              'operational-state': 'DISABLED',
#                                                                                                              'parent-node-edge-point': {'node-edge-point-uuid': '30000040-0000-0000-0000-000000047423',
#                                                                                                                                         'node-uuid': '00000030-0000-0000-0000-000000047277',
#                                                                                                                                         'topology-uuid': '00000020-0000-0000-0000-000000000003'},
#                                                                                                              'tapi-adva:adva-connection-end-point-spec': {},
#                                                                                                              'termination-state': 'LT_PERMENANTLY_TERMINATED',
#                                                                                                              'uuid': '30000050-0000-0000-0000-000000047423'}]},
#                                                     'termination-direction': 'BIDIRECTIONAL',
#                                                     'termination-state': 'LT_PERMENANTLY_TERMINATED',
#                                                     'uuid': '30000040-0000-0000-0000-000000047423'},
#                                                    {'administrative-state': 'UNLOCKED',
#                                                     'layer-protocol-name': 'PHOTONIC_MEDIA',
#                                                     'lifecycle-state': 'INSTALLED',
#                                                     'link-port-direction': 'BIDIRECTIONAL',
#                                                     'mapped-service-interface-point': [],
#                                                     'name': [{'value': '/ne=172.20.143.64/sh=2/sl=10/pt=N',
#                                                               'value-name': 'INVENTORY_ID'},
#                                                              {'value': 'NODE66/2-10-N',
#                                                               'value-name': 'USER'},
#                                                              {'value': '172.20.143.64/OM-2-10-N',
#                                                               'value-name': 'SYSTEM'}],
#                                                     'operational-state': 'DISABLED',
#                                                     'supported-cep-layer-protocol-qualifier': ['tapi-photonic-media:PHOTONIC_LAYER_QUALIFIER_OTS'],
#                                                     'tapi-connectivity:cep-list': {'connection-end-point': [{'client-node-edge-point': [{'node-edge-point-uuid': '30010040-0000-0000-0000-000000047314',
#                                                                                                                                          'node-uuid': '00000030-0000-0000-0000-000000047277',
#                                                                                                                                          'topology-uuid': '00000020-0000-0000-0000-000000000003'}],
#                                                                                                              'connection-port-direction': 'BIDIRECTIONAL',
#                                                                                                              'layer-protocol-name': 'PHOTONIC_MEDIA',
#                                                                                                              'layer-protocol-qualifier': 'tapi-photonic-media:PHOTONIC_LAYER_QUALIFIER_OTS',
#                                                                                                              'lifecycle-state': 'INSTALLED',
#                                                                                                              'name': [{'value': '/ne=172.20.143.64/sh=2/sl=10/pt=N',
#                                                                                                                        'value-name': 'INVENTORY_ID'},
#                                                                                                                       {'value': 'NODE66/2-10-N',
#                                                                                                                        'value-name': 'USER'},
#                                                                                                                       {'value': '172.20.143.64/OM-2-10-N',
#                                                                                                                        'value-name': 'SYSTEM'}],
#                                                                                                              'operational-state': 'DISABLED',
#                                                                                                              'parent-node-edge-point': {'node-edge-point-uuid': '30000040-0000-0000-0000-000000047314',
#                                                                                                                                         'node-uuid': '00000030-0000-0000-0000-000000047277',
#                                                                                                                                         'topology-uuid': '00000020-0000-0000-0000-000000000003'},
#                                                                                                              'tapi-adva:adva-connection-end-point-spec': {},
#                                                                                                              'termination-state': 'LT_PERMENANTLY_TERMINATED',
#                                                                                                              'uuid': '30000050-0000-0000-0000-000000047314'}]},
#                                                     'termination-direction': 'BIDIRECTIONAL',
#                                                     'termination-state': 'LT_PERMENANTLY_TERMINATED',
#                                                     'uuid': '30000040-0000-0000-0000-000000047314'},
#                                                    {'administrative-state': 'UNLOCKED',
#                                                     'layer-protocol-name': 'PHOTONIC_MEDIA',
#                                                     'lifecycle-state': 'INSTALLED',
#                                                     'link-port-direction': 'BIDIRECTIONAL',
#                                                     'mapped-service-interface-point': [],
#                                                     'name': [{'value': '/ne=172.20.143.64/sh=2/sl=12/pt=N',
#                                                               'value-name': 'INVENTORY_ID'},
#                                                              {'value': 'NODE66/2-12-N',
#                                                               'value-name': 'USER'},
#                                                              {'value': '172.20.143.64/OM-2-12-N',
#                                                               'value-name': 'SYSTEM'}],
#                                                     'operational-state': 'DISABLED',
#                                                     'supported-cep-layer-protocol-qualifier': ['tapi-photonic-media:PHOTONIC_LAYER_QUALIFIER_OTS'],
#                                                     'tapi-connectivity:cep-list': {'connection-end-point': [{'client-node-edge-point': [{'node-edge-point-uuid': '30010040-0000-0000-0000-000000047378',
#                                                                                                                                          'node-uuid': '00000030-0000-0000-0000-000000047277',
#                                                                                                                                          'topology-uuid': '00000020-0000-0000-0000-000000000003'}],
#                                                                                                              'connection-port-direction': 'BIDIRECTIONAL',
#                                                                                                              'layer-protocol-name': 'PHOTONIC_MEDIA',
#                                                                                                              'layer-protocol-qualifier': 'tapi-photonic-media:PHOTONIC_LAYER_QUALIFIER_OTS',
#                                                                                                              'lifecycle-state': 'INSTALLED',
#                                                                                                              'name': [{'value': '/ne=172.20.143.64/sh=2/sl=12/pt=N',
#                                                                                                                        'value-name': 'INVENTORY_ID'},
#                                                                                                                       {'value': 'NODE66/2-12-N',
#                                                                                                                        'value-name': 'USER'},
#                                                                                                                       {'value': '172.20.143.64/OM-2-12-N',
#                                                                                                                        'value-name': 'SYSTEM'}],
#                                                                                                              'operational-state': 'DISABLED',
#                                                                                                              'parent-node-edge-point': {'node-edge-point-uuid': '30000040-0000-0000-0000-000000047378',
#                                                                                                                                         'node-uuid': '00000030-0000-0000-0000-000000047277',
#                                                                                                                                         'topology-uuid': '00000020-0000-0000-0000-000000000003'},
#                                                                                                              'tapi-adva:adva-connection-end-point-spec': {},
#                                                                                                              'termination-state': 'LT_PERMENANTLY_TERMINATED',
#                                                                                                              'uuid': '30000050-0000-0000-0000-000000047378'}]},
#                                                     'termination-direction': 'BIDIRECTIONAL',
#                                                     'termination-state': 'LT_PERMENANTLY_TERMINATED',
#                                                     'uuid': '30000040-0000-0000-0000-000000047378'},
#                                                    {'administrative-state': 'UNLOCKED',
#                                                     'layer-protocol-name': 'PHOTONIC_MEDIA',
#                                                     'lifecycle-state': 'INSTALLED',
#                                                     'link-port-direction': 'BIDIRECTIONAL',
#                                                     'mapped-service-interface-point': [],
#                                                     'name': [{'value': '/ne=172.20.143.64/sh=2/sl=12/pt=N',
#                                                               'value-name': 'INVENTORY_ID'},
#                                                              {'value': 'NODE66/2-12-N',
#                                                               'value-name': 'USER'},
#                                                              {'value': '172.20.143.64/OM-2-12-N',
#                                                               'value-name': 'SYSTEM'}],
#                                                     'operational-state': 'DISABLED',
#                                                     'supported-cep-layer-protocol-qualifier': ['tapi-photonic-media:PHOTONIC_LAYER_QUALIFIER_OMS'],
#                                                     'tapi-connectivity:cep-list': {'connection-end-point': [{'client-node-edge-point': [],
# ...
#                                                     'lifecycle-state': 'INSTALLED',
#                                                     'link-port-direction': 'BIDIRECTIONAL',
#                                                     'mapped-service-interface-point': [],
#                                                     'name': [{'value': '/ne=172.20.143.63/sh=2/sl=4/pt=N',
#                                                               'value-name': 'INVENTORY_ID'},
#                                                              {'value': 'NODE64/2-4-N',
#                                                               'value-name': 'USER'},
#                                                              {'value': '172.20.143.63/OM-2-4-N',
#                                                               'value-name': 'SYSTEM'}],
#                                                     'operational-state': 'DISABLED',
#                                                     'supported-cep-layer-protocol-qualifier': ['tapi-photonic-media:PHOTONIC_LAYER_QUALIFIER_OMS'],
#                                                     'tapi-connectivity:cep-list': {'connection-end-point': [{'client-node-edge-point': [{'node-edge-point-uuid': '30040040-0000-0000-0000-000000046072',
#                                                                                                                                          'node-uuid': '00000030-0000-0000-0000-000000045758',
#                                                                                                                                          'topology-uuid': '00000020-0000-0000-0000-000000000003'}],
#                                                                                                              'connection-port-direction': 'BIDIRECTIONAL',
#                                                                                                              'layer-protocol-name': 'PHOTONIC_MEDIA',
#                                                                                                              'layer-protocol-qualifier': 'tapi-photonic-media:PHOTONIC_LAYER_QUALIFIER_OMS',
#                                                                                                              'lifecycle-state': 'INSTALLED',
#                                                                                                              'name': [{'value': '/ne=172.20.143.63/sh=2/sl=4/pt=N',
#                                                                                                                        'value-name': 'INVENTORY_ID'},
#                                                                                                                       {'value': 'NODE64/2-4-N',
#                                                                                                                        'value-name': 'USER'},
#                                                                                                                       {'value': '172.20.143.63/OM-2-4-N',
#                                                                                                                        'value-name': 'SYSTEM'}],
#                                                                                                              'operational-state': 'DISABLED',
#                                                                                                              'parent-node-edge-point': {'node-edge-point-uuid': '30010040-0000-0000-0000-000000046072',
#                                                                                                                                         'node-uuid': '00000030-0000-0000-0000-000000045758',
#                                                                                                                                         'topology-uuid': '00000020-0000-0000-0000-000000000003'},
#                                                                                                              'tapi-adva:adva-connection-end-point-spec': {},
#                                                                                                              'termination-state': 'LT_PERMENANTLY_TERMINATED',
#                                                                                                              'uuid': '30010050-0000-0000-0000-000000046072'}]},
#                                                     'termination-direction': 'BIDIRECTIONAL',
#                                                     'termination-state': 'LT_PERMENANTLY_TERMINATED',
#                                                     'uuid': '30010040-0000-0000-0000-000000046072'},
#                                                    {'administrative-state': 'UNLOCKED',
#                                                     'layer-protocol-name': 'PHOTONIC_MEDIA',
#                                                     'lifecycle-state': 'INSTALLED',
#                                                     'link-port-direction': 'BIDIRECTIONAL',
#                                                     'mapped-service-interface-point': [],
#                                                     'name': [{'value': '/ne=172.20.143.63/sh=2/sl=1/pt=N',
#                                                               'value-name': 'INVENTORY_ID'},
#                                                              {'value': 'NODE64/2-1-N',
#                                                               'value-name': 'USER'},
#                                                              {'value': '172.20.143.63/OM-2-1-N',
#                                                               'value-name': 'SYSTEM'}],
#                                                     'operational-state': 'DISABLED',
#                                                     'supported-cep-layer-protocol-qualifier': ['tapi-photonic-media:PHOTONIC_LAYER_QUALIFIER_OCH'],
#                                                     'tapi-connectivity:cep-list': {'connection-end-point': []},
#                                                     'tapi-photonic-media:media-channel-node-edge-point-spec': {'mc-pool': {'available-spectrum': [{'frequency-constraint': {'adjustment-granularity': 'G_50GHZ',
#                                                                                                                                                                             'grid-type': 'DWDM'},
#                                                                                                                                                    'lower-frequency': '191212500',
#                                                                                                                                                    'upper-frequency': '196125000'}],
#                                                                                                                            'occupied-spectrum': [],
#                                                                                                                            'supportable-spectrum': [{'frequency-constraint': {'adjustment-granularity': 'G_50GHZ',
#                                                                                                                                                                               'grid-type': 'DWDM'},
#                                                                                                                                                      'lower-frequency': '191212500',
#                                                                                                                                                      'upper-frequency': '196125000'}]}},
#                                                     'termination-direction': 'BIDIRECTIONAL',
#                                                     'termination-state': 'TERMINATED_BIDIRECTIONAL',
#                                                     'uuid': '30040040-0000-0000-0000-000000045772'},
#                                                    {'administrative-state': 'UNLOCKED',
#                                                     'layer-protocol-name': 'PHOTONIC_MEDIA',
#                                                     'lifecycle-state': 'INSTALLED',
#                                                     'link-port-direction': 'BIDIRECTIONAL',
#                                                     'mapped-service-interface-point': [],
#                                                     'name': [{'value': '/ne=172.20.143.63/sh=2/sl=4/pt=N',
#                                                               'value-name': 'INVENTORY_ID'},
#                                                              {'value': 'NODE64/2-4-N',
#                                                               'value-name': 'USER'},
#                                                              {'value': '172.20.143.63/OM-2-4-N',
#                                                               'value-name': 'SYSTEM'}],
#                                                     'operational-state': 'DISABLED',
#                                                     'supported-cep-layer-protocol-qualifier': ['tapi-photonic-media:PHOTONIC_LAYER_QUALIFIER_OCH'],
#                                                     'tapi-connectivity:cep-list': {'connection-end-point': []},
#                                                     'tapi-photonic-media:media-channel-node-edge-point-spec': {'mc-pool': {'available-spectrum': [{'frequency-constraint': {'adjustment-granularity': 'G_50GHZ',
#                                                                                                                                                                             'grid-type': 'DWDM'},
#                                                                                                                                                    'lower-frequency': '191212500',
#                                                                                                                                                    'upper-frequency': '196125000'}],
#                                                                                                                            'occupied-spectrum': [],
#                                                                                                                            'supportable-spectrum': [{'frequency-constraint': {'adjustment-granularity': 'G_50GHZ',
#                                                                                                                                                                               'grid-type': 'DWDM'},
#                                                                                                                                                      'lower-frequency': '191212500',
#                                                                                                                                                      'upper-frequency': '196125000'}]}},
#                                                     'termination-direction': 'BIDIRECTIONAL',
#                                                     'termination-state': 'TERMINATED_BIDIRECTIONAL',
#                                                     'uuid': '30040040-0000-0000-0000-000000046072'},
#                                                    {'administrative-state': 'LOCKED',
#                                                     'layer-protocol-name': 'PHOTONIC_MEDIA',
#                                                     'lifecycle-state': 'PLANNED',
#                                                     'link-port-direction': 'BIDIRECTIONAL',
#                                                     'mapped-service-interface-point': [{'service-interface-point-uuid': '00000010-0000-0000-0000-000000046095'}],
#                                                     'name': [{'value': '/ne=172.20.143.63/sh=3/sl=1/pt=N',
#                                                               'value-name': 'INVENTORY_ID'},
#                                                              {'value': 'NODE64/3-1-N',
#                                                               'value-name': 'USER'},
#                                                              {'value': '172.20.143.63/PTP-3-1-N',
#                                                               'value-name': 'SYSTEM'}],
#                                                     'operational-state': 'DISABLED',
#                                                     'supported-cep-layer-protocol-qualifier': ['tapi-photonic-media:PHOTONIC_LAYER_QUALIFIER_OCH'],
#                                                     'tapi-connectivity:cep-list': {'connection-end-point': []},
#                                                     'tapi-photonic-media:media-channel-node-edge-point-spec': {'mc-pool': {'available-spectrum': [],
#                                                                                                                            'occupied-spectrum': [],
#                                                                                                                            'supportable-spectrum': []}},
#                                                     'termination-direction': 'BIDIRECTIONAL',
#                                                     'termination-state': 'TERMINATED_BIDIRECTIONAL',
#                                                     'uuid': '30040040-0000-0000-0000-000000046095'},
#                                                    {'administrative-state': 'LOCKED',
#                                                     'layer-protocol-name': 'DSR',
#                                                     'lifecycle-state': 'PLANNED',
#                                                     'link-port-direction': 'BIDIRECTIONAL',
#                                                     'mapped-service-interface-point': [{'service-interface-point-uuid': '00000010-0000-0000-0000-000000046095'}],
#                                                     'name': [{'value': '/ne=172.20.143.63/sh=3/sl=1/pt=N',
#                                                               'value-name': 'INVENTORY_ID'},
#                                                              {'value': 'NODE64/3-1-N',
#                                                               'value-name': 'USER'},
#                                                              {'value': '172.20.143.63/PTP-3-1-N',
#                                                               'value-name': 'SYSTEM'}],
#                                                     'operational-state': 'DISABLED',
#                                                     'supported-cep-layer-protocol-qualifier': ['tapi-dsr:DIGITAL_SIGNAL_TYPE_100_GigE'],
#                                                     'tapi-connectivity:cep-list': {'connection-end-point': []},
#                                                     'termination-direction': 'BIDIRECTIONAL',
#                                                     'termination-state': 'TERMINATED_BIDIRECTIONAL',
#                                                     'uuid': '20000040-0000-0000-0000-000000046095'}],
#                          'tapi-adva:adva-node-spec': {'adva-administrative-state': 'IN_SERVICE',
#                                                       'cp-mode': 'CPD',
#                                                       'ip-address': '172.20.143.63',
#                                                       'ne-type': 'FSP 3000R7',
#                                                       'reachability-status': 'REACHABLE',
#                                                       'serial-number': '',
#                                                       'sw-version': '20.3.1',
#                                                       'user-label': 'NODE64'},
#                          'uuid': '00000030-0000-0000-0000-000000045758'}]}

# %%
with open("context.json", "rt", encoding="UTF-8") as file:
    text = file.read()
context = json.loads(text)
